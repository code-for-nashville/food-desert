# %%
# Start
import os
import time
print("last time run: {}".format(time.strftime("%c")))
print(os.getcwd())
print(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# last time run: Sat May  4 11:56:11 2019
# /home/bren/Home/python/Libraries/data/census/dir01
# gis

# %%
# Style
from IPython.core.display  import HTML
from IPython.core.debugger import set_trace

def css_styling():
    styles = open("/home/bren/Home/python/Jupyter/Jupyter Notebooks/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
# @import url('http://fonts.googleapis.com/css?family=Source+Code+Pro');
# @import url('http://fonts.googleapis.com/css?family=Vollkorn');
# @import url('http://fonts.googleapis.com/css?family=Arimo');
# @import url('http://fonts.googleapis.com/css?family=Fira_sans');
#
#     /* Make the notebook cells take almost all available width */
#     .container {
#         width: 99% !important;
#     }
#
#     /* Prevent the edit cell highlight box from getting clipped;
#      * important so that it also works when cell is in edit mode*/
#     div.cell.selected {
#         border-left-width: 0% !important;
#     }
#
#     div.cell{
#         width: 99%;
#         margin-left: 0% !important;
#         margin-right: auto;
#     }
#     div.text_cell code {
#         background: transparent;
#         color: #000000;
#         font-weight: 600;
#         font-size: 11pt;
#         font-style: bold;
#         font-family:  'Source Code Pro', Consolas, monocco, monospace;
#    }
#     h1 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
# 	}
#
#     div.input_area {
#         background: #F6F6F9;
#         border: 1px solid #586e75;
#     }
#
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 30pt;
#         line-height: 100%;
#         color:#c76c0c;
#         margin-bottom: 0.5em;
#         margin-top: 1em;
#         display: block;
#         white-space: wrap;
#         text-align: left;
#     }
#     h2 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#         text-align: left;
#     }
#     .text_cell_render h2 {
#         font-weight: 200;
#         font-size: 16pt;
#         font-style: italic;
#         line-height: 100%;
#         color:#c76c0c;
#         margin-bottom: 0.5em;
#         margin-top: 1.5em;
#         display: block;
#         white-space: wrap;
#         text-align: left;
#     }
#     h3 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#     }
#     .text_cell_render h3 {
#         font-weight: 200;
#         font-size: 14pt;
#         line-height: 100%;
#         color:#d77c0c;
#         margin-bottom: 0.5em;
#         margin-top: 2em;
#         display: block;
#         white-space: wrap;
#         text-align: left;
#     }
#     h4 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#     }
#     .text_cell_render h4 {
#         font-weight: 100;
#         font-size: 14pt;
#         color:#d77c0c;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     h5 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#     }
#     .text_cell_render h5 {
#         font-weight: 200;
#         font-style: normal;
#         color: #1d3b84;
#         font-size: 16pt;
#         margin-bottom: 0em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     div.text_cell_render{
#         font-family: 'Fira sans', verdana,arial,sans-serif;
#         line-height: 125%;
#         font-size: 115%;
#         text-align:justify;
#         text-justify:inter-word;
#     }
#     div.output_subarea.output_text.output_pyout {
#         overflow-x: auto;
#         overflow-y: scroll;
#         max-height: 50000px;
#     }
#     div.output_subarea.output_stream.output_stdout.output_text {
#         overflow-x: auto;
#         overflow-y: scroll;
#         max-height: 50000px;
#     }
#     div.output_wrapper{
#         margin-top:0.2em;
#         margin-bottom:0.2em;
# }
#
#     code{
#       font-size: 70%;
#     }
#     .rendered_html code{
#     background-color: transparent;
#     }
#     ul{
#         margin: 2em;
#     }
#     ul li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#     }
#     ul li li{
#         padding-left: 0.2em;
#         margin-bottom: 0.2em;
#         margin-top: 0.2em;
#     }
#     ol{
#         margin: 2em;
#     }
#     ol li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#     }
#     ul li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.2em;
#     }
#     a:link{
#        font-weight: bold;
#        color:#447adb;
#     }
#     a:visited{
#        font-weight: bold;
#        color: #1d3b84;
#     }
#     a:hover{
#        font-weight: bold;
#        color: #1d3b84;
#     }
#     a:focus{
#        font-weight: bold;
#        color:#447adb;
#     }
#     a:active{
#        font-weight: bold;
#        color:#447adb;
#     }
#     .rendered_html :link {
#        text-decoration: underline;
#     }
#     .rendered_html :hover {
#        text-decoration: none;
#     }
#     .rendered_html :visited {
#       text-decoration: none;
#     }
#     .rendered_html :focus {
#       text-decoration: none;
#     }
#     .rendered_html :active {
#       text-decoration: none;
#     }
#     .warning{
#         color: rgb( 240, 20, 20 )
#     }
#     hr {
#       color: #f3f3f3;
#       background-color: #f3f3f3;
#       height: 1px;
#     }
#     blockquote{
#       display:block;
#       background: #fcfcfc;
#       border-left: 5px solid #c76c0c;
#       font-family: 'Open sans',verdana,arial,sans-serif;
#       width:680px;
#       padding: 10px 10px 10px 10px;
#       text-align:justify;
#       text-justify:inter-word;
#       }
#       blockquote p {
#         margin-bottom: 0;
#         line-height: 125%;
#         font-size: 100%;
#       }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     scale:100,
#                         availableFonts: [],
#                         preferredFont:null,
#                         webFont: "TeX",
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
# setup TOC
import sys
toc_path = '/home/bren/miniconda3/lib/python3.7/site-packages/IPythonTOC-1.2.0-py3.7.egg'
if toc_path not in sys.path:
    sys.path.append(toc_path)
else:
    print('toc_path in sys.path already')

from IPythonTOC import IPythonTOC
toc = IPythonTOC()
# Out:
# toc_path in sys.path already

# %%
# imports
from glob import glob
from matplotlib import pyplot as plt, rcParams
import numpy as np
import pandas as pd

# %matplotlib inline
plt.style.use("ggplot")
rcParams["figure.figsize"] = (14, 7)

import IPython, platform
# %reload_ext watermark
print("Python  {}".format(platform.python_version()))
# %watermark -v -m -p IPython,matplotlib,numpy,pandas,sys
# Out:
# Python  3.7.1
# CPython 3.7.1
# IPython 7.2.0
#
# IPython 7.2.0
# matplotlib 3.0.2
# numpy 1.15.4
# pandas 0.24.1
# sys 3.7.1 | packaged by conda-forge | (default, Feb 18 2019, 01:42:00)
# [GCC 7.3.0]
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 4.9.0-8-amd64
# machine    : x86_64
# processor  :
# CPU cores  : 8
# interpreter: 64bit

# %%
#pd.set_option(""display.height"", 10)
#pd.set_option(""display.max_rows"", 20)
pd.set_option("display.max_colwidth", 500)
pd.set_option("display.expand_frame_repr", True)
pd.set_option("display.width", 1000)

# %% [markdown]
# <a id='Table_of_Contents'></a>
# ### Table of Contents
#
# [ACS_17_5YR_B08122](#ACS_17_5YR_B08122) TRANS TO WORK BY POVERTY PAST 12 MO BY County
#
# [ACS_17_5YR_S1701](#ACS_17_5YR_S1701) POVERTY Last 12 MO BY CENSUS TRACT
#
# [ACS_17_1YR_S1703](#ACS_17_1YR_S1703) POVERTY last 12 MONTHS by County
#
# [ACS_17_5YR_S2201](#ACS_17_5YR_S2201) SNAP by Census Tract
#
#  [ACS_17_1YR_S2201](#ACS_17_1YR_S2201) SNAP by County

# %%
get_ipython().set_next_input(
    toc.genTOCMarkdownCell(
        "ACS_17_1YR_S1703"
    ))
print(toc.genTOCEntry())
# Out:
# [ACS_17_1YR_S1703](#ACS_17_1YR_S1703)

# %%
ls
# Out:
# ACS_17_1YR_S1703_metadata.csv   ACS_17_5YR_S1701.txt
# ACS_17_1YR_S1703.txt            ACS_17_5YR_S1701_with_ann.csv
# ACS_17_1YR_S1703_with_ann.csv   ACS_17_5YR_S2201_metadata.csv
# ACS_17_1YR_S2201_metadata.csv   ACS_17_5YR_S2201.txt
# ACS_17_1YR_S2201.txt            ACS_17_5YR_S2201_with_ann.csv
# ACS_17_1YR_S2201_with_ann.csv   aff_download0.zip
# ACS_17_5YR_B08122_metadata.csv  aff_download_readme_ann.txt
# ACS_17_5YR_B08122.txt           aff_download.zip
# ACS_17_5YR_B08122_with_ann.csv  Tract Trans2Work Poverty SNAP.ipynb
# ACS_17_5YR_S1701_metadata.csv

# %% [markdown]
# <a id='ACS_17_5YR_B08122'></a>
# ## ACS_17_5YR_B08122 TRANS TO WORK BY POVERTY PAST 12 MO BY County
#
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# # ACS_17_5YR_B08122.txt
#
# MEANS OF TRANSPORTATION TO WORK BY POVERTY STATUS IN THE PAST 12 MONTHS BY County
#
# Universe: Workers 16 years and over for whom poverty status is determined
#
# Although the American Community Survey (ACS) produces population, demographic and housing unit estimates, it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities, and towns and estimates of housing units for states and counties.
#
#
# Supporting documentation on code lists, subject definitions, data accuracy, and statistical testing can be found on the American Community Survey website in the Technical Documentation section.
#
# Sample size and data quality measures (including coverage rates, allocation rates, and response rates) can be found on the American Community Survey website in the Methodology section.
#
#
# Source:  U.S. Census Bureau, 2013-2017 American Community Survey 5-Year Estimates
#
#
# Explanation of Symbols:An '**' entry in the margin of error column indicates that either no sample observations or too few sample observations were available to compute a standard error and thus the margin of error. A statistical test is not appropriate.
# An '-' entry in the estimate column indicates that either no sample observations or too few sample observations were available to compute an estimate, or a ratio of medians cannot be calculated because one or both of the median estimates falls in the lowest interval or upper interval of an open-ended distribution.
# An '-' following a median estimate means the median falls in the lowest interval of an open-ended distribution.
# An '+' following a median estimate means the median falls in the upper interval of an open-ended distribution.
# An '***' entry in the margin of error column indicates that the median falls in the lowest interval or upper interval of an open-ended distribution. A statistical test is not appropriate.
# An '*****' entry in the margin of error column indicates that the estimate is controlled. A statistical test for sampling variability is not appropriate.
# An 'N' entry in the estimate and margin of error columns indicates that data for this geographic area cannot be displayed because the number of sample cases is too small.
# An '(X)' means that the estimate is not applicable or not available.
#
#
# Data are based on a sample and are subject to sampling variability. The degree of uncertainty for an estimate arising from sampling variability is represented through the use of a margin of error. The value shown here is the 90 percent margin of error. The margin of error can be interpreted roughly as providing a 90 percent probability that the interval defined by the estimate minus the margin of error and the estimate plus the margin of error (the lower and upper confidence bounds) contains the true value. In addition to sampling variability, the ACS estimates are subject to nonsampling error (for a discussion of nonsampling variability, see Accuracy of the Data).  The effect of nonsampling error is not represented in these tables.
#
#
# Workers include members of the Armed Forces and civilians who were at work last week.
#
#
# While the 2013-2017 American Community Survey (ACS) data generally reflect the February 2013 Office of Management and Budget (OMB) definitions of metropolitan and micropolitan statistical areas; in certain instances the names, codes, and boundaries of the principal cities shown in ACS tables may differ from the OMB definitions due to differences in the effective dates of the geographic entities.
#
#
# Estimates of urban and rural populations, housing units, and characteristics reflect boundaries of urban areas defined based on Census 2010 data. As a result, data for urban and rural areas from the ACS do not necessarily reflect the results of ongoing urbanization.

# %%
metaB08122 = pd.read_csv('ACS_17_5YR_B08122_metadata.csv')
metaB08122
# Out:
#                GEO.id                                                                                                                      Id
# 0             GEO.id2                                                                                                                     Id2
# 1   GEO.display-label                                                                                                               Geography
# 2           HD01_VD01                                                                                                        Estimate; Total:
# 3           HD02_VD01                                                                                                 Margin of Error; Total:
# 4           HD01_VD03                                                               Estimate; Total: - Below 100 percent of the poverty level
# 5           HD02_VD03                                                        Margin of Error; Total: - Below 100 percent of the poverty level
# 6           HD01_VD04                                                              Estimate; Total: - 100 to 149 percent of the poverty level
# 7           HD02_VD04                                                       Margin of Error; Total: - 100 to 149 percent of the poverty level
# 8           HD01_VD05                                                         Estimate; Total: - At or above 150 percent of the poverty level
# 9           HD02_VD05                                                  Margin of Error; Total: - At or above 150 percent of the poverty level
# 10          HD01_VD06                                                                    Estimate; Total: - Car, truck, or van - drove alone:
# 11          HD02_VD06                                                             Margin of Error; Total: - Car, truck, or van - drove alone:
# 12          HD01_VD07                           Estimate; Total: - Car, truck, or van - drove alone: - Below 100 percent of the poverty level
# 13          HD02_VD07                    Margin of Error; Total: - Car, truck, or van - drove alone: - Below 100 percent of the poverty level
# 14          HD01_VD08                          Estimate; Total: - Car, truck, or van - drove alone: - 100 to 149 percent of the poverty level
# 15          HD02_VD08                   Margin of Error; Total: - Car, truck, or van - drove alone: - 100 to 149 percent of the poverty level
# 16          HD01_VD09                     Estimate; Total: - Car, truck, or van - drove alone: - At or above 150 percent of the poverty level
# 17          HD02_VD09              Margin of Error; Total: - Car, truck, or van - drove alone: - At or above 150 percent of the poverty level
# 18          HD01_VD10                                                                      Estimate; Total: - Car, truck, or van - carpooled:
# 19          HD02_VD10                                                               Margin of Error; Total: - Car, truck, or van - carpooled:
# 20          HD01_VD11                             Estimate; Total: - Car, truck, or van - carpooled: - Below 100 percent of the poverty level
# 21          HD02_VD11                      Margin of Error; Total: - Car, truck, or van - carpooled: - Below 100 percent of the poverty level
# 22          HD01_VD12                            Estimate; Total: - Car, truck, or van - carpooled: - 100 to 149 percent of the poverty level
# 23          HD02_VD12                     Margin of Error; Total: - Car, truck, or van - carpooled: - 100 to 149 percent of the poverty level
# 24          HD01_VD13                       Estimate; Total: - Car, truck, or van - carpooled: - At or above 150 percent of the poverty level
# 25          HD02_VD13                Margin of Error; Total: - Car, truck, or van - carpooled: - At or above 150 percent of the poverty level
# 26          HD01_VD14                                                           Estimate; Total: - Public transportation (excluding taxicab):
# 27          HD02_VD14                                                    Margin of Error; Total: - Public transportation (excluding taxicab):
# 28          HD01_VD15                  Estimate; Total: - Public transportation (excluding taxicab): - Below 100 percent of the poverty level
# 29          HD02_VD15           Margin of Error; Total: - Public transportation (excluding taxicab): - Below 100 percent of the poverty level
# 30          HD01_VD16                 Estimate; Total: - Public transportation (excluding taxicab): - 100 to 149 percent of the poverty level
# 31          HD02_VD16          Margin of Error; Total: - Public transportation (excluding taxicab): - 100 to 149 percent of the poverty level
# 32          HD01_VD17            Estimate; Total: - Public transportation (excluding taxicab): - At or above 150 percent of the poverty level
# 33          HD02_VD17     Margin of Error; Total: - Public transportation (excluding taxicab): - At or above 150 percent of the poverty level
# 34          HD01_VD18                                                                                              Estimate; Total: - Walked:
# 35          HD02_VD18                                                                                       Margin of Error; Total: - Walked:
# 36          HD01_VD19                                                     Estimate; Total: - Walked: - Below 100 percent of the poverty level
# 37          HD02_VD19                                              Margin of Error; Total: - Walked: - Below 100 percent of the poverty level
# 38          HD01_VD20                                                    Estimate; Total: - Walked: - 100 to 149 percent of the poverty level
# 39          HD02_VD20                                             Margin of Error; Total: - Walked: - 100 to 149 percent of the poverty level
# 40          HD01_VD21                                               Estimate; Total: - Walked: - At or above 150 percent of the poverty level
# 41          HD02_VD21                                        Margin of Error; Total: - Walked: - At or above 150 percent of the poverty level
# 42          HD01_VD22                                                        Estimate; Total: - Taxicab, motorcycle, bicycle, or other means:
# 43          HD02_VD22                                                 Margin of Error; Total: - Taxicab, motorcycle, bicycle, or other means:
# 44          HD01_VD23               Estimate; Total: - Taxicab, motorcycle, bicycle, or other means: - Below 100 percent of the poverty level
# 45          HD02_VD23        Margin of Error; Total: - Taxicab, motorcycle, bicycle, or other means: - Below 100 percent of the poverty level
# 46          HD01_VD24              Estimate; Total: - Taxicab, motorcycle, bicycle, or other means: - 100 to 149 percent of the poverty level
# 47          HD02_VD24       Margin of Error; Total: - Taxicab, motorcycle, bicycle, or other means: - 100 to 149 percent of the poverty level
# 48          HD01_VD25         Estimate; Total: - Taxicab, motorcycle, bicycle, or other means: - At or above 150 percent of the poverty level
# 49          HD02_VD25  Margin of Error; Total: - Taxicab, motorcycle, bicycle, or other means: - At or above 150 percent of the poverty level
# 50          HD01_VD26                                                                                      Estimate; Total: - Worked at home:
# 51          HD02_VD26                                                                               Margin of Error; Total: - Worked at home:
# 52          HD01_VD27                                             Estimate; Total: - Worked at home: - Below 100 percent of the poverty level
# 53          HD02_VD27                                      Margin of Error; Total: - Worked at home: - Below 100 percent of the poverty level
# 54          HD01_VD28                                            Estimate; Total: - Worked at home: - 100 to 149 percent of the poverty level
# 55          HD02_VD28                                     Margin of Error; Total: - Worked at home: - 100 to 149 percent of the poverty level
# 56          HD01_VD29                                       Estimate; Total: - Worked at home: - At or above 150 percent of the poverty level
# 57          HD02_VD29                                Margin of Error; Total: - Worked at home: - At or above 150 percent of the poverty level

# %%
dataB08122 = pd.read_csv('ACS_17_5YR_B08122_with_ann.csv')
dataB08122.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 59 columns):
# GEO.id               96 non-null object
# GEO.id2              96 non-null object
# GEO.display-label    96 non-null object
# HD01_VD01            96 non-null object
# HD02_VD01            96 non-null object
# HD01_VD03            96 non-null object
# HD02_VD03            96 non-null object
# HD01_VD04            96 non-null object
# HD02_VD04            96 non-null object
# HD01_VD05            96 non-null object
# HD02_VD05            96 non-null object
# HD01_VD06            96 non-null object
# HD02_VD06            96 non-null object
# HD01_VD07            96 non-null object
# HD02_VD07            96 non-null object
# HD01_VD08            96 non-null object
# HD02_VD08            96 non-null object
# HD01_VD09            96 non-null object
# HD02_VD09            96 non-null object
# HD01_VD10            96 non-null object
# HD02_VD10            96 non-null object
# HD01_VD11            96 non-null object
# HD02_VD11            96 non-null object
# HD01_VD12            96 non-null object
# HD02_VD12            96 non-null object
# HD01_VD13            96 non-null object
# HD02_VD13            96 non-null object
# HD01_VD14            96 non-null object
# HD02_VD14            96 non-null object
# HD01_VD15            96 non-null object
# HD02_VD15            96 non-null object
# HD01_VD16            96 non-null object
# HD02_VD16            96 non-null object
# HD01_VD17            96 non-null object
# HD02_VD17            96 non-null object
# HD01_VD18            96 non-null object
# HD02_VD18            96 non-null object
# HD01_VD19            96 non-null object
# HD02_VD19            96 non-null object
# HD01_VD20            96 non-null object
# HD02_VD20            96 non-null object
# HD01_VD21            96 non-null object
# HD02_VD21            96 non-null object
# HD01_VD22            96 non-null object
# HD02_VD22            96 non-null object
# HD01_VD23            96 non-null object
# HD02_VD23            96 non-null object
# HD01_VD24            96 non-null object
# HD02_VD24            96 non-null object
# HD01_VD25            96 non-null object
# HD02_VD25            96 non-null object
# HD01_VD26            96 non-null object
# HD02_VD26            96 non-null object
# HD01_VD27            96 non-null object
# HD02_VD27            96 non-null object
# HD01_VD28            96 non-null object
# HD02_VD28            96 non-null object
# HD01_VD29            96 non-null object
# HD02_VD29            96 non-null object
# dtypes: object(59)
# memory usage: 44.3+ KB

# %%
dataB08122['GEO.display-label'].head()
# Out:
# 0                     Geography
# 1    Anderson County, Tennessee
# 2     Bedford County, Tennessee
# 3      Benton County, Tennessee
# 4     Bledsoe County, Tennessee
# Name: GEO.display-label, dtype: object

# %% [markdown]
# ## ACS_17_1YR_S1703 POVERTY last 12 MONTHS by County
# <a id='ACS_17_1YR_S1703'></a>
#
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# # ACS_17_1YR_S1703
#
# SELECTED CHARACTERISTICS OF PEOPLE AT SPECIFIED LEVELS OF POVERTY IN THE PAST 12 MONTHS by Counth
#
# Although the American Community Survey (ACS) produces population, demographic and housing unit estimates, it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities, and towns and estimates of housing units for states and counties.
#
#
# Supporting documentation on code lists, subject definitions, data accuracy, and statistical testing can be found on the American Community Survey website in the Technical Documentation section.
#
# Sample size and data quality measures (including coverage rates, allocation rates, and response rates) can be found on the American Community Survey website in the Methodology section.
#
#
# Source:  U.S. Census Bureau, 2017 American Community Survey 1-Year Estimates
#
#
# Explanation of Symbols:An '**' entry in the margin of error column indicates that either no sample observations or too few sample observations were available to compute a standard error and thus the margin of error. A statistical test is not appropriate.
# An '-' entry in the estimate column indicates that either no sample observations or too few sample observations were available to compute an estimate, or a ratio of medians cannot be calculated because one or both of the median estimates falls in the lowest interval or upper interval of an open-ended distribution.
# An '-' following a median estimate means the median falls in the lowest interval of an open-ended distribution.
# An '+' following a median estimate means the median falls in the upper interval of an open-ended distribution.
# An '***' entry in the margin of error column indicates that the median falls in the lowest interval or upper interval of an open-ended distribution. A statistical test is not appropriate.
# An '*****' entry in the margin of error column indicates that the estimate is controlled. A statistical test for sampling variability is not appropriate.
# An 'N' entry in the estimate and margin of error columns indicates that data for this geographic area cannot be displayed because the number of sample cases is too small.
# An '(X)' means that the estimate is not applicable or not available.
#
#
# Data are based on a sample and are subject to sampling variability. The degree of uncertainty for an estimate arising from sampling variability is represented through the use of a margin of error. The value shown here is the 90 percent margin of error. The margin of error can be interpreted roughly as providing a 90 percent probability that the interval defined by the estimate minus the margin of error and the estimate plus the margin of error (the lower and upper confidence bounds) contains the true value. In addition to sampling variability, the ACS estimates are subject to nonsampling error (for a discussion of nonsampling variability, see Accuracy of the Data).  The effect of nonsampling error is not represented in these tables.
#
#
# While the 2017 American Community Survey (ACS) data generally reflect the July 2015 Office of Management and Budget (OMB) delineations of metropolitan and micropolitan statistical areas, in certain instances the names, codes, and boundaries of the principal cities shown in ACS tables may differ from the OMB delineations due to differences in the effective dates of the geographic entities.
#
#
# Estimates of urban and rural populations, housing units, and characteristics reflect boundaries of urban areas defined based on Census 2010 data. As a result, data for urban and rural areas from the ACS do not necessarily reflect the results of ongoing urbanization.

# %%
metaS1703 = pd.read_csv('ACS_17_1YR_S1703_metadata.csv')
metaS1703
# Out:
#                 GEO.id                                                                                                                                             Id
# 0              GEO.id2                                                                                                                                            Id2
# 1    GEO.display-label                                                                                                                                      Geography
# 2        HC01_EST_VC01                                                                              Total; Estimate; Population for whom poverty status is determined
# 3        HC01_MOE_VC01                                                                       Total; Margin of Error; Population for whom poverty status is determined
# 4        HC02_EST_VC01                                          Less than 50 percent of the poverty level; Estimate; Population for whom poverty status is determined
# 5        HC02_MOE_VC01                                   Less than 50 percent of the poverty level; Margin of Error; Population for whom poverty status is determined
# 6        HC03_EST_VC01                                         Less than 100 percent of the poverty level; Estimate; Population for whom poverty status is determined
# 7        HC03_MOE_VC01                                  Less than 100 percent of the poverty level; Margin of Error; Population for whom poverty status is determined
# 8        HC04_EST_VC01                                         Less than 125 percent of the poverty level; Estimate; Population for whom poverty status is determined
# 9        HC04_MOE_VC01                                  Less than 125 percent of the poverty level; Margin of Error; Population for whom poverty status is determined
# 10       HC01_EST_VC03                                                                                                                    Total; Estimate; SEX - Male
# 11       HC01_MOE_VC03                                                                                                             Total; Margin of Error; SEX - Male
# 12       HC02_EST_VC03                                                                                Less than 50 percent of the poverty level; Estimate; SEX - Male
# 13       HC02_MOE_VC03                                                                         Less than 50 percent of the poverty level; Margin of Error; SEX - Male
# 14       HC03_EST_VC03                                                                               Less than 100 percent of the poverty level; Estimate; SEX - Male
# 15       HC03_MOE_VC03                                                                        Less than 100 percent of the poverty level; Margin of Error; SEX - Male
# 16       HC04_EST_VC03                                                                               Less than 125 percent of the poverty level; Estimate; SEX - Male
# 17       HC04_MOE_VC03                                                                        Less than 125 percent of the poverty level; Margin of Error; SEX - Male
# 18       HC01_EST_VC04                                                                                                                  Total; Estimate; SEX - Female
# 19       HC01_MOE_VC04                                                                                                           Total; Margin of Error; SEX - Female
# 20       HC02_EST_VC04                                                                              Less than 50 percent of the poverty level; Estimate; SEX - Female
# 21       HC02_MOE_VC04                                                                       Less than 50 percent of the poverty level; Margin of Error; SEX - Female
# 22       HC03_EST_VC04                                                                             Less than 100 percent of the poverty level; Estimate; SEX - Female
# 23       HC03_MOE_VC04                                                                      Less than 100 percent of the poverty level; Margin of Error; SEX - Female
# 24       HC04_EST_VC04                                                                             Less than 125 percent of the poverty level; Estimate; SEX - Female
# 25       HC04_MOE_VC04                                                                      Less than 125 percent of the poverty level; Margin of Error; SEX - Female
# 26       HC01_EST_VC07                                                                                                          Total; Estimate; AGE - Under 18 years
# 27       HC01_MOE_VC07                                                                                                   Total; Margin of Error; AGE - Under 18 years
# 28       HC02_EST_VC07                                                                      Less than 50 percent of the poverty level; Estimate; AGE - Under 18 years
# 29       HC02_MOE_VC07                                                               Less than 50 percent of the poverty level; Margin of Error; AGE - Under 18 years
# ..                 ...                                                                                                                                            ...
# 252      HC02_EST_VC48                                                   Less than 50 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years
# 253      HC02_MOE_VC48                                            Less than 50 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years
# 254      HC03_EST_VC48                                                  Less than 100 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years
# 255      HC03_MOE_VC48                                           Less than 100 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years
# 256      HC04_EST_VC48                                                  Less than 125 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years
# 257      HC04_MOE_VC48                                           Less than 125 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years
# 258      HC01_EST_VC49                                                        Total; Estimate; WORK STATUS - Population 16 to 64 years - Worked full-time, year-round
# 259      HC01_MOE_VC49                                                 Total; Margin of Error; WORK STATUS - Population 16 to 64 years - Worked full-time, year-round
# 260      HC02_EST_VC49                    Less than 50 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years - Worked full-time, year-round
# 261      HC02_MOE_VC49             Less than 50 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years - Worked full-time, year-round
# 262      HC03_EST_VC49                   Less than 100 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years - Worked full-time, year-round
# 263      HC03_MOE_VC49            Less than 100 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years - Worked full-time, year-round
# 264      HC04_EST_VC49                   Less than 125 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years - Worked full-time, year-round
# 265      HC04_MOE_VC49            Less than 125 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years - Worked full-time, year-round
# 266      HC01_EST_VC50                                              Total; Estimate; WORK STATUS - Population 16 to 64 years - Worked less than full-time, year-round
# 267      HC01_MOE_VC50                                       Total; Margin of Error; WORK STATUS - Population 16 to 64 years - Worked less than full-time, year-round
# 268      HC02_EST_VC50          Less than 50 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years - Worked less than full-time, year-round
# 269      HC02_MOE_VC50   Less than 50 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years - Worked less than full-time, year-round
# 270      HC03_EST_VC50         Less than 100 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years - Worked less than full-time, year-round
# 271      HC03_MOE_VC50  Less than 100 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years - Worked less than full-time, year-round
# 272      HC04_EST_VC50         Less than 125 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years - Worked less than full-time, year-round
# 273      HC04_MOE_VC50  Less than 125 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years - Worked less than full-time, year-round
# 274      HC01_EST_VC51                                                                        Total; Estimate; WORK STATUS - Population 16 to 64 years - Did not work
# 275      HC01_MOE_VC51                                                                 Total; Margin of Error; WORK STATUS - Population 16 to 64 years - Did not work
# 276      HC02_EST_VC51                                    Less than 50 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years - Did not work
# 277      HC02_MOE_VC51                             Less than 50 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years - Did not work
# 278      HC03_EST_VC51                                   Less than 100 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years - Did not work
# 279      HC03_MOE_VC51                            Less than 100 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years - Did not work
# 280      HC04_EST_VC51                                   Less than 125 percent of the poverty level; Estimate; WORK STATUS - Population 16 to 64 years - Did not work
# 281      HC04_MOE_VC51                            Less than 125 percent of the poverty level; Margin of Error; WORK STATUS - Population 16 to 64 years - Did not work
#
# [282 rows x 2 columns]

# %%
dataS1703 = pd.read_csv('ACS_17_1YR_S1703_with_ann.csv')
dataS1703.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Columns: 283 entries, GEO.id to HC04_MOE_VC51
# dtypes: object(283)
# memory usage: 6.7+ KB

# %%
dataS1703['GEO.display-label'].head()
# Out:
# 0                     Geography
# 1    Davidson County, Tennessee
# 2      Shelby County, Tennessee
# Name: GEO.display-label, dtype: object

# %% [markdown]
# <a id='ACS_17_5YR_S1701'></a>
# ## ACS_17_5YR_S1701 POVERTY PAST 12 MO BY CENSUS TRACT
#
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# # ACS_17_5YR_S1701.txt
#
# POVERTY STATUS IN THE PAST 12 MONTHS BY CENSUS TRACT
#
# Although the American Community Survey (ACS) produces population, demographic and housing unit estimates, it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities, and towns and estimates of housing units for states and counties.
#
#
# Supporting documentation on code lists, subject definitions, data accuracy, and statistical testing can be found on the American Community Survey website in the Technical Documentation section.
#
# Sample size and data quality measures (including coverage rates, allocation rates, and response rates) can be found on the American Community Survey website in the Methodology section.
#
#
# Source:  U.S. Census Bureau, 2013-2017 American Community Survey 5-Year Estimates
#
#
# Explanation of Symbols:An '**' entry in the margin of error column indicates that either no sample observations or too few sample observations were available to compute a standard error and thus the margin of error. A statistical test is not appropriate.
# An '-' entry in the estimate column indicates that either no sample observations or too few sample observations were available to compute an estimate, or a ratio of medians cannot be calculated because one or both of the median estimates falls in the lowest interval or upper interval of an open-ended distribution.
# An '-' following a median estimate means the median falls in the lowest interval of an open-ended distribution.
# An '+' following a median estimate means the median falls in the upper interval of an open-ended distribution.
# An '***' entry in the margin of error column indicates that the median falls in the lowest interval or upper interval of an open-ended distribution. A statistical test is not appropriate.
# An '*****' entry in the margin of error column indicates that the estimate is controlled. A statistical test for sampling variability is not appropriate.
# An 'N' entry in the estimate and margin of error columns indicates that data for this geographic area cannot be displayed because the number of sample cases is too small.
# An '(X)' means that the estimate is not applicable or not available.
#
#
# Data are based on a sample and are subject to sampling variability. The degree of uncertainty for an estimate arising from sampling variability is represented through the use of a margin of error. The value shown here is the 90 percent margin of error. The margin of error can be interpreted roughly as providing a 90 percent probability that the interval defined by the estimate minus the margin of error and the estimate plus the margin of error (the lower and upper confidence bounds) contains the true value. In addition to sampling variability, the ACS estimates are subject to nonsampling error (for a discussion of nonsampling variability, see Accuracy of the Data).  The effect of nonsampling error is not represented in these tables.
#
#
# While the 2013-2017 American Community Survey (ACS) data generally reflect the February 2013 Office of Management and Budget (OMB) definitions of metropolitan and micropolitan statistical areas; in certain instances the names, codes, and boundaries of the principal cities shown in ACS tables may differ from the OMB definitions due to differences in the effective dates of the geographic entities.
#
#
# Estimates of urban and rural populations, housing units, and characteristics reflect boundaries of urban areas defined based on Census 2010 data. As a result, data for urban and rural areas from the ACS do not necessarily reflect the results of ongoing urbanization.

# %%
metaS1701 = pd.read_csv('ACS_17_5YR_S1701_metadata.csv')
metaS1701
# Out:
#                 GEO.id                                                                                                           Id
# 0              GEO.id2                                                                                                          Id2
# 1    GEO.display-label                                                                                                    Geography
# 2        HC01_EST_VC01                                            Total; Estimate; Population for whom poverty status is determined
# 3        HC01_MOE_VC01                                     Total; Margin of Error; Population for whom poverty status is determined
# 4        HC02_EST_VC01                              Below poverty level; Estimate; Population for whom poverty status is determined
# 5        HC02_MOE_VC01                       Below poverty level; Margin of Error; Population for whom poverty status is determined
# 6        HC03_EST_VC01                      Percent below poverty level; Estimate; Population for whom poverty status is determined
# 7        HC03_MOE_VC01               Percent below poverty level; Margin of Error; Population for whom poverty status is determined
# 8        HC01_EST_VC03                                                                        Total; Estimate; AGE - Under 18 years
# 9        HC01_MOE_VC03                                                                 Total; Margin of Error; AGE - Under 18 years
# 10       HC02_EST_VC03                                                          Below poverty level; Estimate; AGE - Under 18 years
# 11       HC02_MOE_VC03                                                   Below poverty level; Margin of Error; AGE - Under 18 years
# 12       HC03_EST_VC03                                                  Percent below poverty level; Estimate; AGE - Under 18 years
# 13       HC03_MOE_VC03                                           Percent below poverty level; Margin of Error; AGE - Under 18 years
# 14       HC01_EST_VC04                                                        Total; Estimate; AGE - Under 18 years - Under 5 years
# 15       HC01_MOE_VC04                                                 Total; Margin of Error; AGE - Under 18 years - Under 5 years
# 16       HC02_EST_VC04                                          Below poverty level; Estimate; AGE - Under 18 years - Under 5 years
# 17       HC02_MOE_VC04                                   Below poverty level; Margin of Error; AGE - Under 18 years - Under 5 years
# 18       HC03_EST_VC04                                  Percent below poverty level; Estimate; AGE - Under 18 years - Under 5 years
# 19       HC03_MOE_VC04                           Percent below poverty level; Margin of Error; AGE - Under 18 years - Under 5 years
# 20       HC01_EST_VC05                                                        Total; Estimate; AGE - Under 18 years - 5 to 17 years
# 21       HC01_MOE_VC05                                                 Total; Margin of Error; AGE - Under 18 years - 5 to 17 years
# 22       HC02_EST_VC05                                          Below poverty level; Estimate; AGE - Under 18 years - 5 to 17 years
# 23       HC02_MOE_VC05                                   Below poverty level; Margin of Error; AGE - Under 18 years - 5 to 17 years
# 24       HC03_EST_VC05                                  Percent below poverty level; Estimate; AGE - Under 18 years - 5 to 17 years
# 25       HC03_MOE_VC05                           Percent below poverty level; Margin of Error; AGE - Under 18 years - 5 to 17 years
# 26       HC01_EST_VC06                       Total; Estimate; AGE - Under 18 years - Related children of householder under 18 years
# 27       HC01_MOE_VC06                Total; Margin of Error; AGE - Under 18 years - Related children of householder under 18 years
# 28       HC02_EST_VC06         Below poverty level; Estimate; AGE - Under 18 years - Related children of householder under 18 years
# 29       HC02_MOE_VC06  Below poverty level; Margin of Error; AGE - Under 18 years - Related children of householder under 18 years
# ..                 ...                                                                                                          ...
# 338      HC01_EST_VC73                                                                           Total; Estimate; 75 years and over
# 339      HC01_MOE_VC73                                                                    Total; Margin of Error; 75 years and over
# 340      HC02_EST_VC73                                                             Below poverty level; Estimate; 75 years and over
# 341      HC02_MOE_VC73                                                      Below poverty level; Margin of Error; 75 years and over
# 342      HC03_EST_VC73                                                     Percent below poverty level; Estimate; 75 years and over
# 343      HC03_MOE_VC73                                              Percent below poverty level; Margin of Error; 75 years and over
# 344      HC01_EST_VC75                                     Total; Estimate; Mean income deficit for unrelated individuals (dollars)
# 345      HC01_MOE_VC75                              Total; Margin of Error; Mean income deficit for unrelated individuals (dollars)
# 346      HC02_EST_VC75                       Below poverty level; Estimate; Mean income deficit for unrelated individuals (dollars)
# 347      HC02_MOE_VC75                Below poverty level; Margin of Error; Mean income deficit for unrelated individuals (dollars)
# 348      HC03_EST_VC75               Percent below poverty level; Estimate; Mean income deficit for unrelated individuals (dollars)
# 349      HC03_MOE_VC75        Percent below poverty level; Margin of Error; Mean income deficit for unrelated individuals (dollars)
# 350      HC01_EST_VC77                                          Total; Estimate; Worked full-time, year-round in the past 12 months
# 351      HC01_MOE_VC77                                   Total; Margin of Error; Worked full-time, year-round in the past 12 months
# 352      HC02_EST_VC77                            Below poverty level; Estimate; Worked full-time, year-round in the past 12 months
# 353      HC02_MOE_VC77                     Below poverty level; Margin of Error; Worked full-time, year-round in the past 12 months
# 354      HC03_EST_VC77                    Percent below poverty level; Estimate; Worked full-time, year-round in the past 12 months
# 355      HC03_MOE_VC77             Percent below poverty level; Margin of Error; Worked full-time, year-round in the past 12 months
# 356      HC01_EST_VC78                                Total; Estimate; Worked less than full-time, year-round in the past 12 months
# 357      HC01_MOE_VC78                         Total; Margin of Error; Worked less than full-time, year-round in the past 12 months
# 358      HC02_EST_VC78                  Below poverty level; Estimate; Worked less than full-time, year-round in the past 12 months
# 359      HC02_MOE_VC78           Below poverty level; Margin of Error; Worked less than full-time, year-round in the past 12 months
# 360      HC03_EST_VC78          Percent below poverty level; Estimate; Worked less than full-time, year-round in the past 12 months
# 361      HC03_MOE_VC78   Percent below poverty level; Margin of Error; Worked less than full-time, year-round in the past 12 months
# 362      HC01_EST_VC79                                                                                Total; Estimate; Did not work
# 363      HC01_MOE_VC79                                                                         Total; Margin of Error; Did not work
# 364      HC02_EST_VC79                                                                  Below poverty level; Estimate; Did not work
# 365      HC02_MOE_VC79                                                           Below poverty level; Margin of Error; Did not work
# 366      HC03_EST_VC79                                                          Percent below poverty level; Estimate; Did not work
# 367      HC03_MOE_VC79                                                   Percent below poverty level; Margin of Error; Did not work
#
# [368 rows x 2 columns]

# %%
dataS1701 = pd.read_csv('ACS_17_5YR_S1701_with_ann.csv')
dataS1701.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1498 entries, 0 to 1497
# Columns: 369 entries, GEO.id to HC03_MOE_VC79
# dtypes: object(369)
# memory usage: 4.2+ MB

# %%
dataS1701['GEO.display-label'].head()
# Out:
# 0                                          Geography
# 1       Census Tract 201, Anderson County, Tennessee
# 2    Census Tract 202.01, Anderson County, Tennessee
# 3    Census Tract 202.02, Anderson County, Tennessee
# 4       Census Tract 203, Anderson County, Tennessee
# Name: GEO.display-label, dtype: object

# %% [markdown]
# <a id='ACS_17_5YR_S2201'></a>
# ## ACS_17_5YR_S2201 SNAP by Census Tract
#
#
# [Table of Contents](#Table_of_Contents)

# %%
# %load ACS_17_1YR_S2201.txt
S2201
FOOD STAMPS/Supplemental Nutrition Assistance Program (SNAP) 

Although the American Community Survey (ACS) produces population, demographic and housing unit estimates, it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities, and towns and estimates of housing units for states and counties.


Supporting documentation on code lists, subject definitions, data accuracy, and statistical testing can be found on the American Community Survey website in the Technical Documentation section.

Sample size and data quality measures (including coverage rates, allocation rates, and response rates) can be found on the American Community Survey website in the Methodology section.


Source:  U.S. Census Bureau, 2017 American Community Survey 1-Year Estimates


Explanation of Symbols:An '**' entry in the margin of error column indicates that either no sample observations or too few sample observations were available to compute a standard error and thus the margin of error. A statistical test is not appropriate.
An '-' entry in the estimate column indicates that either no sample observations or too few sample observations were available to compute an estimate, or a ratio of medians cannot be calculated because one or both of the median estimates falls in the lowest interval or upper interval of an open-ended distribution.
An '-' following a median estimate means the median falls in the lowest interval of an open-ended distribution.
An '+' following a median estimate means the median falls in the upper interval of an open-ended distribution.
An '***' entry in the margin of error column indicates that the median falls in the lowest interval or upper interval of an open-ended distribution. A statistical test is not appropriate.
An '*****' entry in the margin of error column indicates that the estimate is controlled. A statistical test for sampling variability is not appropriate. 
An 'N' entry in the estimate and margin of error columns indicates that data for this geographic area cannot be displayed because the number of sample cases is too small.
An '(X)' means that the estimate is not applicable or not available.


Data are based on a sample and are subject to sampling variability. The degree of uncertainty for an estimate arising from sampling variability is represented through the use of a margin of error. The value shown here is the 90 percent margin of error. The margin of error can be interpreted roughly as providing a 90 percent probability that the interval defined by the estimate minus the margin of error and the estimate plus the margin of error (the lower and upper confidence bounds) contains the true value. In addition to sampling variability, the ACS estimates are subject to nonsampling error (for a discussion of nonsampling variability, see Accuracy of the Data).  The effect of nonsampling error is not represented in these tables.


While the 2017 American Community Survey (ACS) data generally reflect the July 2015 Office of Management and Budget (OMB) delineations of metropolitan and micropolitan statistical areas, in certain instances the names, codes, and boundaries of the principal cities shown in ACS tables may differ from the OMB delineations due to differences in the effective dates of the geographic entities.


Estimates of urban and rural populations, housing units, and characteristics reflect boundaries of urban areas defined based on Census 2010 data. As a result, data for urban and rural areas from the ACS do not necessarily reflect the results of ongoing urbanization.

# %% [markdown]
# # ACS_17_5YR_S2201.txt
#
# FOOD STAMPS/Supplemental Nutrition Assistance Program (SNAP) by Census Tract
#
# Although the American Community Survey (ACS) produces population, demographic and housing unit estimates, it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities, and towns and estimates of housing units for states and counties.
#
#
# Supporting documentation on code lists, subject definitions, data accuracy, and statistical testing can be found on the American Community Survey website in the Technical Documentation section.
#
# Sample size and data quality measures (including coverage rates, allocation rates, and response rates) can be found on the American Community Survey website in the Methodology section.
#
#
# Source:  U.S. Census Bureau, 2013-2017 American Community Survey 5-Year Estimates
#
#
# Explanation of Symbols:An '**' entry in the margin of error column indicates that either no sample observations or too few sample observations were available to compute a standard error and thus the margin of error. A statistical test is not appropriate.
# An '-' entry in the estimate column indicates that either no sample observations or too few sample observations were available to compute an estimate, or a ratio of medians cannot be calculated because one or both of the median estimates falls in the lowest interval or upper interval of an open-ended distribution.
# An '-' following a median estimate means the median falls in the lowest interval of an open-ended distribution.
# An '+' following a median estimate means the median falls in the upper interval of an open-ended distribution.
# An '***' entry in the margin of error column indicates that the median falls in the lowest interval or upper interval of an open-ended distribution. A statistical test is not appropriate.
# An '*****' entry in the margin of error column indicates that the estimate is controlled. A statistical test for sampling variability is not appropriate.
# An 'N' entry in the estimate and margin of error columns indicates that data for this geographic area cannot be displayed because the number of sample cases is too small.
# An '(X)' means that the estimate is not applicable or not available.
#
#
# Data are based on a sample and are subject to sampling variability. The degree of uncertainty for an estimate arising from sampling variability is represented through the use of a margin of error. The value shown here is the 90 percent margin of error. The margin of error can be interpreted roughly as providing a 90 percent probability that the interval defined by the estimate minus the margin of error and the estimate plus the margin of error (the lower and upper confidence bounds) contains the true value. In addition to sampling variability, the ACS estimates are subject to nonsampling error (for a discussion of nonsampling variability, see Accuracy of the Data).  The effect of nonsampling error is not represented in these tables.
#
#
# While the 2013-2017 American Community Survey (ACS) data generally reflect the February 2013 Office of Management and Budget (OMB) definitions of metropolitan and micropolitan statistical areas; in certain instances the names, codes, and boundaries of the principal cities shown in ACS tables may differ from the OMB definitions due to differences in the effective dates of the geographic entities.
#
#
# Estimates of urban and rural populations, housing units, and characteristics reflect boundaries of urban areas defined based on Census 2010 data. As a result, data for urban and rural areas from the ACS do not necessarily reflect the results of ongoing urbanization.

# %%
metaS2201 = pd.read_csv('ACS_17_5YR_S2201_metadata.csv')
metaS2201
# Out:
#                 GEO.id                                                                                                                                Id
# 0              GEO.id2                                                                                                                               Id2
# 1    GEO.display-label                                                                                                                         Geography
# 2        HC01_EST_VC01                                                                                                       Total; Estimate; Households
# 3        HC01_MOE_VC01                                                                                                Total; Margin of Error; Households
# 4        HC02_EST_VC01                                                                                                     Percent; Estimate; Households
# 5        HC02_MOE_VC01                                                                                              Percent; Margin of Error; Households
# 6        HC03_EST_VC01                                                                       Households receiving food stamps/SNAP; Estimate; Households
# 7        HC03_MOE_VC01                                                                Households receiving food stamps/SNAP; Margin of Error; Households
# 8        HC04_EST_VC01                                                               Percent households receiving food stamps/SNAP; Estimate; Households
# 9        HC04_MOE_VC01                                                        Percent households receiving food stamps/SNAP; Margin of Error; Households
# 10       HC05_EST_VC01                                                                   Households not receiving food stamps/SNAP; Estimate; Households
# 11       HC05_MOE_VC01                                                            Households not receiving food stamps/SNAP; Margin of Error; Households
# 12       HC06_EST_VC01                                                           Percent households not receiving food stamps/SNAP; Estimate; Households
# 13       HC06_MOE_VC01                                                    Percent households not receiving food stamps/SNAP; Margin of Error; Households
# 14       HC01_EST_VC02                                                       Total; Estimate; With one or more people in the household 60 years and over
# 15       HC01_MOE_VC02                                                Total; Margin of Error; With one or more people in the household 60 years and over
# 16       HC02_EST_VC02                                                     Percent; Estimate; With one or more people in the household 60 years and over
# 17       HC02_MOE_VC02                                              Percent; Margin of Error; With one or more people in the household 60 years and over
# 18       HC03_EST_VC02                       Households receiving food stamps/SNAP; Estimate; With one or more people in the household 60 years and over
# 19       HC03_MOE_VC02                Households receiving food stamps/SNAP; Margin of Error; With one or more people in the household 60 years and over
# 20       HC04_EST_VC02               Percent households receiving food stamps/SNAP; Estimate; With one or more people in the household 60 years and over
# 21       HC04_MOE_VC02        Percent households receiving food stamps/SNAP; Margin of Error; With one or more people in the household 60 years and over
# 22       HC05_EST_VC02                   Households not receiving food stamps/SNAP; Estimate; With one or more people in the household 60 years and over
# 23       HC05_MOE_VC02            Households not receiving food stamps/SNAP; Margin of Error; With one or more people in the household 60 years and over
# 24       HC06_EST_VC02           Percent households not receiving food stamps/SNAP; Estimate; With one or more people in the household 60 years and over
# 25       HC06_MOE_VC02    Percent households not receiving food stamps/SNAP; Margin of Error; With one or more people in the household 60 years and over
# 26       HC01_EST_VC03                                                                     Total; Estimate; No people in the household 60 years and over
# 27       HC01_MOE_VC03                                                              Total; Margin of Error; No people in the household 60 years and over
# 28       HC02_EST_VC03                                                                   Percent; Estimate; No people in the household 60 years and over
# 29       HC02_MOE_VC03                                                            Percent; Margin of Error; No people in the household 60 years and over
# ..                 ...                                                                                                                               ...
# 428      HC04_EST_VC49                    Percent households receiving food stamps/SNAP; Estimate; WORK STATUS - Families - No workers in past 12 months
# 429      HC04_MOE_VC49             Percent households receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - No workers in past 12 months
# 430      HC05_EST_VC49                        Households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - No workers in past 12 months
# 431      HC05_MOE_VC49                 Households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - No workers in past 12 months
# 432      HC06_EST_VC49                Percent households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - No workers in past 12 months
# 433      HC06_MOE_VC49         Percent households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - No workers in past 12 months
# 434      HC01_EST_VC50                                                              Total; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 435      HC01_MOE_VC50                                                       Total; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 436      HC02_EST_VC50                                                            Percent; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 437      HC02_MOE_VC50                                                     Percent; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 438      HC03_EST_VC50                              Households receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 439      HC03_MOE_VC50                       Households receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 440      HC04_EST_VC50                      Percent households receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 441      HC04_MOE_VC50               Percent households receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 442      HC05_EST_VC50                          Households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 443      HC05_MOE_VC50                   Households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 444      HC06_EST_VC50                  Percent households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 445      HC06_MOE_VC50           Percent households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 446      HC01_EST_VC51                                                     Total; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 447      HC01_MOE_VC51                                              Total; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
# 448      HC02_EST_VC51                                                   Percent; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 449      HC02_MOE_VC51                                            Percent; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
# 450      HC03_EST_VC51                     Households receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 451      HC03_MOE_VC51              Households receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
# 452      HC04_EST_VC51             Percent households receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 453      HC04_MOE_VC51      Percent households receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
# 454      HC05_EST_VC51                 Households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 455      HC05_MOE_VC51          Households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
# 456      HC06_EST_VC51         Percent households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 457      HC06_MOE_VC51  Percent households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
#
# [458 rows x 2 columns]

# %%
dataS2201 = pd.read_csv('ACS_17_5YR_S2201_with_ann.csv')
dataS2201.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1498 entries, 0 to 1497
# Columns: 459 entries, GEO.id to HC06_MOE_VC51
# dtypes: object(459)
# memory usage: 5.2+ MB

# %%
dataS2201['GEO.display-label'].head()
# Out:
# 0                                          Geography
# 1       Census Tract 201, Anderson County, Tennessee
# 2    Census Tract 202.01, Anderson County, Tennessee
# 3    Census Tract 202.02, Anderson County, Tennessee
# 4       Census Tract 203, Anderson County, Tennessee
# Name: GEO.display-label, dtype: object

# %% [markdown]
# ## ACS_17_1YR_S2201 SNAP by County
# <a id='ACS_17_1YR_S2201'></a>
#
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# #  ACS_17_1YR_S2201
#
# FOOD STAMPS/Supplemental Nutrition Assistance Program (SNAP)  by County
#
# Although the American Community Survey (ACS) produces population, demographic and housing unit estimates, it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities, and towns and estimates of housing units for states and counties.
#
#
# Supporting documentation on code lists, subject definitions, data accuracy, and statistical testing can be found on the American Community Survey website in the Technical Documentation section.
#
# Sample size and data quality measures (including coverage rates, allocation rates, and response rates) can be found on the American Community Survey website in the Methodology section.
#
#
# Source:  U.S. Census Bureau, 2017 American Community Survey 1-Year Estimates
#
#
# Explanation of Symbols:An '**' entry in the margin of error column indicates that either no sample observations or too few sample observations were available to compute a standard error and thus the margin of error. A statistical test is not appropriate.
# An '-' entry in the estimate column indicates that either no sample observations or too few sample observations were available to compute an estimate, or a ratio of medians cannot be calculated because one or both of the median estimates falls in the lowest interval or upper interval of an open-ended distribution.
# An '-' following a median estimate means the median falls in the lowest interval of an open-ended distribution.
# An '+' following a median estimate means the median falls in the upper interval of an open-ended distribution.
# An '***' entry in the margin of error column indicates that the median falls in the lowest interval or upper interval of an open-ended distribution. A statistical test is not appropriate.
# An '*****' entry in the margin of error column indicates that the estimate is controlled. A statistical test for sampling variability is not appropriate.
# An 'N' entry in the estimate and margin of error columns indicates that data for this geographic area cannot be displayed because the number of sample cases is too small.
# An '(X)' means that the estimate is not applicable or not available.
#
#
# Data are based on a sample and are subject to sampling variability. The degree of uncertainty for an estimate arising from sampling variability is represented through the use of a margin of error. The value shown here is the 90 percent margin of error. The margin of error can be interpreted roughly as providing a 90 percent probability that the interval defined by the estimate minus the margin of error and the estimate plus the margin of error (the lower and upper confidence bounds) contains the true value. In addition to sampling variability, the ACS estimates are subject to nonsampling error (for a discussion of nonsampling variability, see Accuracy of the Data).  The effect of nonsampling error is not represented in these tables.
#
#
# While the 2017 American Community Survey (ACS) data generally reflect the July 2015 Office of Management and Budget (OMB) delineations of metropolitan and micropolitan statistical areas, in certain instances the names, codes, and boundaries of the principal cities shown in ACS tables may differ from the OMB delineations due to differences in the effective dates of the geographic entities.
#
#
# Estimates of urban and rural populations, housing units, and characteristics reflect boundaries of urban areas defined based on Census 2010 data. As a result, data for urban and rural areas from the ACS do not necessarily reflect the results of ongoing urbanization.

# %%
meta1YR_S2201 = pd.read_csv('ACS_17_1YR_S2201_metadata.csv')
meta1YR_S2201
# Out:
#                 GEO.id                                                                                                                                Id
# 0              GEO.id2                                                                                                                               Id2
# 1    GEO.display-label                                                                                                                         Geography
# 2        HC01_EST_VC01                                                                                                       Total; Estimate; Households
# 3        HC01_MOE_VC01                                                                                                Total; Margin of Error; Households
# 4        HC02_EST_VC01                                                                                                     Percent; Estimate; Households
# 5        HC02_MOE_VC01                                                                                              Percent; Margin of Error; Households
# 6        HC03_EST_VC01                                                                       Households receiving food stamps/SNAP; Estimate; Households
# 7        HC03_MOE_VC01                                                                Households receiving food stamps/SNAP; Margin of Error; Households
# 8        HC04_EST_VC01                                                               Percent households receiving food stamps/SNAP; Estimate; Households
# 9        HC04_MOE_VC01                                                        Percent households receiving food stamps/SNAP; Margin of Error; Households
# 10       HC05_EST_VC01                                                                   Households not receiving food stamps/SNAP; Estimate; Households
# 11       HC05_MOE_VC01                                                            Households not receiving food stamps/SNAP; Margin of Error; Households
# 12       HC06_EST_VC01                                                           Percent households not receiving food stamps/SNAP; Estimate; Households
# 13       HC06_MOE_VC01                                                    Percent households not receiving food stamps/SNAP; Margin of Error; Households
# 14       HC01_EST_VC02                                                       Total; Estimate; With one or more people in the household 60 years and over
# 15       HC01_MOE_VC02                                                Total; Margin of Error; With one or more people in the household 60 years and over
# 16       HC02_EST_VC02                                                     Percent; Estimate; With one or more people in the household 60 years and over
# 17       HC02_MOE_VC02                                              Percent; Margin of Error; With one or more people in the household 60 years and over
# 18       HC03_EST_VC02                       Households receiving food stamps/SNAP; Estimate; With one or more people in the household 60 years and over
# 19       HC03_MOE_VC02                Households receiving food stamps/SNAP; Margin of Error; With one or more people in the household 60 years and over
# 20       HC04_EST_VC02               Percent households receiving food stamps/SNAP; Estimate; With one or more people in the household 60 years and over
# 21       HC04_MOE_VC02        Percent households receiving food stamps/SNAP; Margin of Error; With one or more people in the household 60 years and over
# 22       HC05_EST_VC02                   Households not receiving food stamps/SNAP; Estimate; With one or more people in the household 60 years and over
# 23       HC05_MOE_VC02            Households not receiving food stamps/SNAP; Margin of Error; With one or more people in the household 60 years and over
# 24       HC06_EST_VC02           Percent households not receiving food stamps/SNAP; Estimate; With one or more people in the household 60 years and over
# 25       HC06_MOE_VC02    Percent households not receiving food stamps/SNAP; Margin of Error; With one or more people in the household 60 years and over
# 26       HC01_EST_VC03                                                                     Total; Estimate; No people in the household 60 years and over
# 27       HC01_MOE_VC03                                                              Total; Margin of Error; No people in the household 60 years and over
# 28       HC02_EST_VC03                                                                   Percent; Estimate; No people in the household 60 years and over
# 29       HC02_MOE_VC03                                                            Percent; Margin of Error; No people in the household 60 years and over
# ..                 ...                                                                                                                               ...
# 428      HC04_EST_VC49                    Percent households receiving food stamps/SNAP; Estimate; WORK STATUS - Families - No workers in past 12 months
# 429      HC04_MOE_VC49             Percent households receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - No workers in past 12 months
# 430      HC05_EST_VC49                        Households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - No workers in past 12 months
# 431      HC05_MOE_VC49                 Households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - No workers in past 12 months
# 432      HC06_EST_VC49                Percent households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - No workers in past 12 months
# 433      HC06_MOE_VC49         Percent households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - No workers in past 12 months
# 434      HC01_EST_VC50                                                              Total; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 435      HC01_MOE_VC50                                                       Total; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 436      HC02_EST_VC50                                                            Percent; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 437      HC02_MOE_VC50                                                     Percent; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 438      HC03_EST_VC50                              Households receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 439      HC03_MOE_VC50                       Households receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 440      HC04_EST_VC50                      Percent households receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 441      HC04_MOE_VC50               Percent households receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 442      HC05_EST_VC50                          Households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 443      HC05_MOE_VC50                   Households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 444      HC06_EST_VC50                  Percent households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 1 worker in past 12 months
# 445      HC06_MOE_VC50           Percent households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 1 worker in past 12 months
# 446      HC01_EST_VC51                                                     Total; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 447      HC01_MOE_VC51                                              Total; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
# 448      HC02_EST_VC51                                                   Percent; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 449      HC02_MOE_VC51                                            Percent; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
# 450      HC03_EST_VC51                     Households receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 451      HC03_MOE_VC51              Households receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
# 452      HC04_EST_VC51             Percent households receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 453      HC04_MOE_VC51      Percent households receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
# 454      HC05_EST_VC51                 Households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 455      HC05_MOE_VC51          Households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
# 456      HC06_EST_VC51         Percent households not receiving food stamps/SNAP; Estimate; WORK STATUS - Families - 2 or more workers in past 12 months
# 457      HC06_MOE_VC51  Percent households not receiving food stamps/SNAP; Margin of Error; WORK STATUS - Families - 2 or more workers in past 12 months
#
# [458 rows x 2 columns]

# %%
data1YR_S2201 = pd.read_csv('ACS_17_1YR_S2201_with_ann.csv')
data1YR_S2201.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Columns: 459 entries, GEO.id to HC06_MOE_VC51
# dtypes: object(459)
# memory usage: 75.4+ KB

# %%
data1YR_S2201['GEO.display-label'].head()
# Out:
# 0                     Geography
# 1    Anderson County, Tennessee
# 2      Blount County, Tennessee
# 3     Bradley County, Tennessee
# 4    Davidson County, Tennessee
# Name: GEO.display-label, dtype: object

# %%
ls -tr
# Out:
# aff_download0.zip               ACS_17_5YR_B08122.txt
# ACS_17_5YR_S1701_with_ann.csv   ACS_17_5YR_B08122_metadata.csv
# ACS_17_5YR_S2201_with_ann.csv   ACS_17_1YR_S2201_with_ann.csv
# ACS_17_5YR_S1701.txt            ACS_17_1YR_S2201.txt
# ACS_17_5YR_S1701_metadata.csv   ACS_17_1YR_S2201_metadata.csv
# ACS_17_5YR_S2201.txt            ACS_17_1YR_S1703_with_ann.csv
# ACS_17_5YR_S2201_metadata.csv   ACS_17_1YR_S1703.txt
# aff_download.zip                ACS_17_1YR_S1703_metadata.csv
# aff_download_readme_ann.txt     Tract Trans2Work Poverty SNAP.ipynb
# ACS_17_5YR_B08122_with_ann.csv
