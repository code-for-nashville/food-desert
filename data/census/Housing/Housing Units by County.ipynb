# %%
# Start
import os
import time
print("last time run: {}".format(time.strftime("%c")))
print(os.getcwd())
print(os.environ['CONDA_DEFAULT_ENV'])
# Out:
# last time run: Sat May  4 08:50:27 2019
# /home/bren/Home/python/Libraries/data/census/dir03
# gis

# %%
# Style
from IPython.core.display  import HTML
from IPython.core.debugger import set_trace

def css_styling():
    styles = open("/home/bren/Home/python/Jupyter/Jupyter Notebooks/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
# @import url('http://fonts.googleapis.com/css?family=Source+Code+Pro');
# @import url('http://fonts.googleapis.com/css?family=Vollkorn');
# @import url('http://fonts.googleapis.com/css?family=Arimo');
# @import url('http://fonts.googleapis.com/css?family=Fira_sans');
#
#     /* Make the notebook cells take almost all available width */
#     .container {
#         width: 99% !important;
#     }
#
#     /* Prevent the edit cell highlight box from getting clipped;
#      * important so that it also works when cell is in edit mode*/
#     div.cell.selected {
#         border-left-width: 0% !important;
#     }
#
#     div.cell{
#         width: 99%;
#         margin-left: 0% !important;
#         margin-right: auto;
#     }
#     div.text_cell code {
#         background: transparent;
#         color: #000000;
#         font-weight: 600;
#         font-size: 11pt;
#         font-style: bold;
#         font-family:  'Source Code Pro', Consolas, monocco, monospace;
#    }
#     h1 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
# 	}
#
#     div.input_area {
#         background: #F6F6F9;
#         border: 1px solid #586e75;
#     }
#
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 30pt;
#         line-height: 100%;
#         color:#c76c0c;
#         margin-bottom: 0.5em;
#         margin-top: 1em;
#         display: block;
#         white-space: wrap;
#         text-align: left;
#     }
#     h2 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#         text-align: left;
#     }
#     .text_cell_render h2 {
#         font-weight: 200;
#         font-size: 16pt;
#         font-style: italic;
#         line-height: 100%;
#         color:#c76c0c;
#         margin-bottom: 0.5em;
#         margin-top: 1.5em;
#         display: block;
#         white-space: wrap;
#         text-align: left;
#     }
#     h3 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#     }
#     .text_cell_render h3 {
#         font-weight: 200;
#         font-size: 14pt;
#         line-height: 100%;
#         color:#d77c0c;
#         margin-bottom: 0.5em;
#         margin-top: 2em;
#         display: block;
#         white-space: wrap;
#         text-align: left;
#     }
#     h4 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#     }
#     .text_cell_render h4 {
#         font-weight: 100;
#         font-size: 14pt;
#         color:#d77c0c;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     h5 {
#         font-family: 'Open sans',verdana,arial,sans-serif;
#     }
#     .text_cell_render h5 {
#         font-weight: 200;
#         font-style: normal;
#         color: #1d3b84;
#         font-size: 16pt;
#         margin-bottom: 0em;
#         margin-top: 0.5em;
#         display: block;
#         white-space: nowrap;
#     }
#     div.text_cell_render{
#         font-family: 'Fira sans', verdana,arial,sans-serif;
#         line-height: 125%;
#         font-size: 115%;
#         text-align:justify;
#         text-justify:inter-word;
#     }
#     div.output_subarea.output_text.output_pyout {
#         overflow-x: auto;
#         overflow-y: scroll;
#         max-height: 50000px;
#     }
#     div.output_subarea.output_stream.output_stdout.output_text {
#         overflow-x: auto;
#         overflow-y: scroll;
#         max-height: 50000px;
#     }
#     div.output_wrapper{
#         margin-top:0.2em;
#         margin-bottom:0.2em;
# }
#
#     code{
#       font-size: 70%;
#     }
#     .rendered_html code{
#     background-color: transparent;
#     }
#     ul{
#         margin: 2em;
#     }
#     ul li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#     }
#     ul li li{
#         padding-left: 0.2em;
#         margin-bottom: 0.2em;
#         margin-top: 0.2em;
#     }
#     ol{
#         margin: 2em;
#     }
#     ol li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#     }
#     ul li{
#         padding-left: 0.5em;
#         margin-bottom: 0.5em;
#         margin-top: 0.2em;
#     }
#     a:link{
#        font-weight: bold;
#        color:#447adb;
#     }
#     a:visited{
#        font-weight: bold;
#        color: #1d3b84;
#     }
#     a:hover{
#        font-weight: bold;
#        color: #1d3b84;
#     }
#     a:focus{
#        font-weight: bold;
#        color:#447adb;
#     }
#     a:active{
#        font-weight: bold;
#        color:#447adb;
#     }
#     .rendered_html :link {
#        text-decoration: underline;
#     }
#     .rendered_html :hover {
#        text-decoration: none;
#     }
#     .rendered_html :visited {
#       text-decoration: none;
#     }
#     .rendered_html :focus {
#       text-decoration: none;
#     }
#     .rendered_html :active {
#       text-decoration: none;
#     }
#     .warning{
#         color: rgb( 240, 20, 20 )
#     }
#     hr {
#       color: #f3f3f3;
#       background-color: #f3f3f3;
#       height: 1px;
#     }
#     blockquote{
#       display:block;
#       background: #fcfcfc;
#       border-left: 5px solid #c76c0c;
#       font-family: 'Open sans',verdana,arial,sans-serif;
#       width:680px;
#       padding: 10px 10px 10px 10px;
#       text-align:justify;
#       text-justify:inter-word;
#       }
#       blockquote p {
#         margin-bottom: 0;
#         line-height: 125%;
#         font-size: 100%;
#       }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     scale:100,
#                         availableFonts: [],
#                         preferredFont:null,
#                         webFont: "TeX",
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
# setup TOC
import sys
toc_path = '/home/bren/miniconda3/lib/python3.7/site-packages/IPythonTOC-1.2.0-py3.7.egg'
if toc_path not in sys.path:
    sys.path.append(toc_path)
else:
    print('toc_path in sys.path already')

from IPythonTOC import IPythonTOC
toc = IPythonTOC()
# Out:
# toc_path in sys.path already

# %%
# imports
from matplotlib import pyplot as plt, rcParams
import numpy as np
import pandas as pd

# %matplotlib inline
plt.style.use("ggplot")
rcParams["figure.figsize"] = (14, 7)

import IPython, platform
# %reload_ext watermark
print("Python  {}".format(platform.python_version()))
# %watermark -v -m -p IPython,matplotlib,numpy,pandas,sys
# Out:
# Python  3.7.1
# CPython 3.7.1
# IPython 7.2.0
#
# IPython 7.2.0
# matplotlib 3.0.2
# numpy 1.15.4
# pandas 0.24.1
# sys 3.7.1 | packaged by conda-forge | (default, Feb 18 2019, 01:42:00)
# [GCC 7.3.0]
#
# compiler   : GCC 7.3.0
# system     : Linux
# release    : 4.9.0-8-amd64
# machine    : x86_64
# processor  :
# CPU cores  : 8
# interpreter: 64bit

# %%
#pd.set_option(""display.height"", 10)
#pd.set_option(""display.max_rows"", 20)
pd.set_option("display.max_colwidth", 500)
pd.set_option("display.expand_frame_repr", True)
pd.set_option("display.width", 1000)

# %% [markdown]
# <a id='Table_of_Contents'></a>
# ### Table of Contents
#
# [ACS_17_5YR_B25075](#ACS_17_5YR_B25075) Owner-occupied housing units by County
#
# [ACS_17_5YR_S2506](#ACS_17_5YR_S2506) HOUSING UNITS WITH MORTGAGE By County
#
# [ACS_17_5YR_S2507](#ACS_17_5YR_S2507) HOUSING UNITS WITHOUT MORTGAGE  By County

# %% [markdown]
# ## ACS_17_5YR_B25075 Owner-occupied housing units by County
# <a id='ACS_17_5YR_B25075'></a>
#
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# # ACS_17_5YR_B25075
#
# Housing VALUE
#
# Universe: Owner-occupied housing units by County
#
# Although the American Community Survey (ACS) produces population, demographic and housing unit estimates, it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities, and towns and estimates of housing units for states and counties.
#
#
# Supporting documentation on code lists, subject definitions, data accuracy, and statistical testing can be found on the American Community Survey website in the Technical Documentation section.
#
# Sample size and data quality measures (including coverage rates, allocation rates, and response rates) can be found on the American Community Survey website in the Methodology section.
#
#
# Source:  U.S. Census Bureau, 2013-2017 American Community Survey 5-Year Estimates
#
#
# Explanation of Symbols:An '**' entry in the margin of error column indicates that either no sample observations or too few sample observations were available to compute a standard error and thus the margin of error. A statistical test is not appropriate.
# An '-' entry in the estimate column indicates that either no sample observations or too few sample observations were available to compute an estimate, or a ratio of medians cannot be calculated because one or both of the median estimates falls in the lowest interval or upper interval of an open-ended distribution.
# An '-' following a median estimate means the median falls in the lowest interval of an open-ended distribution.
# An '+' following a median estimate means the median falls in the upper interval of an open-ended distribution.
# An '***' entry in the margin of error column indicates that the median falls in the lowest interval or upper interval of an open-ended distribution. A statistical test is not appropriate.
# An '*****' entry in the margin of error column indicates that the estimate is controlled. A statistical test for sampling variability is not appropriate.
# An 'N' entry in the estimate and margin of error columns indicates that data for this geographic area cannot be displayed because the number of sample cases is too small.
# An '(X)' means that the estimate is not applicable or not available.
#
#
# Data are based on a sample and are subject to sampling variability. The degree of uncertainty for an estimate arising from sampling variability is represented through the use of a margin of error. The value shown here is the 90 percent margin of error. The margin of error can be interpreted roughly as providing a 90 percent probability that the interval defined by the estimate minus the margin of error and the estimate plus the margin of error (the lower and upper confidence bounds) contains the true value. In addition to sampling variability, the ACS estimates are subject to nonsampling error (for a discussion of nonsampling variability, see Accuracy of the Data).  The effect of nonsampling error is not represented in these tables.
#
#
# While the 2013-2017 American Community Survey (ACS) data generally reflect the February 2013 Office of Management and Budget (OMB) definitions of metropolitan and micropolitan statistical areas; in certain instances the names, codes, and boundaries of the principal cities shown in ACS tables may differ from the OMB definitions due to differences in the effective dates of the geographic entities.
#
#
# Estimates of urban and rural populations, housing units, and characteristics reflect boundaries of urban areas defined based on Census 2010 data. As a result, data for urban and rural areas from the ACS do not necessarily reflect the results of ongoing urbanization.

# %%
metaB25075 = pd.read_csv('ACS_17_5YR_B25075_metadata.csv')
metaB25075
# Out:
#                GEO.id                                                  Id
# 0             GEO.id2                                                 Id2
# 1   GEO.display-label                                           Geography
# 2           HD01_VD01                                    Estimate; Total:
# 3           HD02_VD01                             Margin of Error; Total:
# 4           HD01_VD02                Estimate; Total: - Less than $10,000
# 5           HD02_VD02         Margin of Error; Total: - Less than $10,000
# 6           HD01_VD03               Estimate; Total: - $10,000 to $14,999
# 7           HD02_VD03        Margin of Error; Total: - $10,000 to $14,999
# 8           HD01_VD04               Estimate; Total: - $15,000 to $19,999
# 9           HD02_VD04        Margin of Error; Total: - $15,000 to $19,999
# 10          HD01_VD05               Estimate; Total: - $20,000 to $24,999
# 11          HD02_VD05        Margin of Error; Total: - $20,000 to $24,999
# 12          HD01_VD06               Estimate; Total: - $25,000 to $29,999
# 13          HD02_VD06        Margin of Error; Total: - $25,000 to $29,999
# 14          HD01_VD07               Estimate; Total: - $30,000 to $34,999
# 15          HD02_VD07        Margin of Error; Total: - $30,000 to $34,999
# 16          HD01_VD08               Estimate; Total: - $35,000 to $39,999
# 17          HD02_VD08        Margin of Error; Total: - $35,000 to $39,999
# 18          HD01_VD09               Estimate; Total: - $40,000 to $49,999
# 19          HD02_VD09        Margin of Error; Total: - $40,000 to $49,999
# 20          HD01_VD10               Estimate; Total: - $50,000 to $59,999
# 21          HD02_VD10        Margin of Error; Total: - $50,000 to $59,999
# 22          HD01_VD11               Estimate; Total: - $60,000 to $69,999
# 23          HD02_VD11        Margin of Error; Total: - $60,000 to $69,999
# 24          HD01_VD12               Estimate; Total: - $70,000 to $79,999
# 25          HD02_VD12        Margin of Error; Total: - $70,000 to $79,999
# 26          HD01_VD13               Estimate; Total: - $80,000 to $89,999
# 27          HD02_VD13        Margin of Error; Total: - $80,000 to $89,999
# 28          HD01_VD14               Estimate; Total: - $90,000 to $99,999
# 29          HD02_VD14        Margin of Error; Total: - $90,000 to $99,999
# 30          HD01_VD15             Estimate; Total: - $100,000 to $124,999
# 31          HD02_VD15      Margin of Error; Total: - $100,000 to $124,999
# 32          HD01_VD16             Estimate; Total: - $125,000 to $149,999
# 33          HD02_VD16      Margin of Error; Total: - $125,000 to $149,999
# 34          HD01_VD17             Estimate; Total: - $150,000 to $174,999
# 35          HD02_VD17      Margin of Error; Total: - $150,000 to $174,999
# 36          HD01_VD18             Estimate; Total: - $175,000 to $199,999
# 37          HD02_VD18      Margin of Error; Total: - $175,000 to $199,999
# 38          HD01_VD19             Estimate; Total: - $200,000 to $249,999
# 39          HD02_VD19      Margin of Error; Total: - $200,000 to $249,999
# 40          HD01_VD20             Estimate; Total: - $250,000 to $299,999
# 41          HD02_VD20      Margin of Error; Total: - $250,000 to $299,999
# 42          HD01_VD21             Estimate; Total: - $300,000 to $399,999
# 43          HD02_VD21      Margin of Error; Total: - $300,000 to $399,999
# 44          HD01_VD22             Estimate; Total: - $400,000 to $499,999
# 45          HD02_VD22      Margin of Error; Total: - $400,000 to $499,999
# 46          HD01_VD23             Estimate; Total: - $500,000 to $749,999
# 47          HD02_VD23      Margin of Error; Total: - $500,000 to $749,999
# 48          HD01_VD24             Estimate; Total: - $750,000 to $999,999
# 49          HD02_VD24      Margin of Error; Total: - $750,000 to $999,999
# 50          HD01_VD25         Estimate; Total: - $1,000,000 to $1,499,999
# 51          HD02_VD25  Margin of Error; Total: - $1,000,000 to $1,499,999
# 52          HD01_VD26         Estimate; Total: - $1,500,000 to $1,999,999
# 53          HD02_VD26  Margin of Error; Total: - $1,500,000 to $1,999,999
# 54          HD01_VD27               Estimate; Total: - $2,000,000 or more
# 55          HD02_VD27        Margin of Error; Total: - $2,000,000 or more

# %%
dataB25075 = pd.read_csv('ACS_17_5YR_B25075_with_ann.csv')
dataB25075.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 57 columns):
# GEO.id               97 non-null object
# GEO.id2              97 non-null object
# GEO.display-label    97 non-null object
# HD01_VD01            97 non-null object
# HD02_VD01            97 non-null object
# HD01_VD02            97 non-null object
# HD02_VD02            97 non-null object
# HD01_VD03            97 non-null object
# HD02_VD03            97 non-null object
# HD01_VD04            97 non-null object
# HD02_VD04            97 non-null object
# HD01_VD05            97 non-null object
# HD02_VD05            97 non-null object
# HD01_VD06            97 non-null object
# HD02_VD06            97 non-null object
# HD01_VD07            97 non-null object
# HD02_VD07            97 non-null object
# HD01_VD08            97 non-null object
# HD02_VD08            97 non-null object
# HD01_VD09            97 non-null object
# HD02_VD09            97 non-null object
# HD01_VD10            97 non-null object
# HD02_VD10            97 non-null object
# HD01_VD11            97 non-null object
# HD02_VD11            97 non-null object
# HD01_VD12            97 non-null object
# HD02_VD12            97 non-null object
# HD01_VD13            97 non-null object
# HD02_VD13            97 non-null object
# HD01_VD14            97 non-null object
# HD02_VD14            97 non-null object
# HD01_VD15            97 non-null object
# HD02_VD15            97 non-null object
# HD01_VD16            97 non-null object
# HD02_VD16            97 non-null object
# HD01_VD17            97 non-null object
# HD02_VD17            97 non-null object
# HD01_VD18            97 non-null object
# HD02_VD18            97 non-null object
# HD01_VD19            97 non-null object
# HD02_VD19            97 non-null object
# HD01_VD20            97 non-null object
# HD02_VD20            97 non-null object
# HD01_VD21            97 non-null object
# HD02_VD21            97 non-null object
# HD01_VD22            97 non-null object
# HD02_VD22            97 non-null object
# HD01_VD23            97 non-null object
# HD02_VD23            97 non-null object
# HD01_VD24            97 non-null object
# HD02_VD24            97 non-null object
# HD01_VD25            97 non-null object
# HD02_VD25            97 non-null object
# HD01_VD26            97 non-null object
# HD02_VD26            97 non-null object
# HD01_VD27            97 non-null object
# HD02_VD27            97 non-null object
# dtypes: object(57)
# memory usage: 43.3+ KB

# %%
dataB25075['GEO.display-label'].head()
# Out:
# 0                     Geography
# 1                     Tennessee
# 2    Anderson County, Tennessee
# 3     Bedford County, Tennessee
# 4      Benton County, Tennessee
# Name: GEO.display-label, dtype: object

# %%
ls
# Out:
# ACS_17_5YR_B25075_metadata.csv  ACS_17_5YR_S2507_metadata.csv
# ACS_17_5YR_B25075.txt           ACS_17_5YR_S2507.txt
# ACS_17_5YR_B25075_with_ann.csv  ACS_17_5YR_S2507_with_ann.csv
# ACS_17_5YR_S2506_metadata.csv   aff_download3.zip
# ACS_17_5YR_S2506.txt            aff_download_readme_ann.txt
# ACS_17_5YR_S2506_with_ann.csv   data.ipynb

# %% [markdown]
# # ACS_17_5YR_S2506.txt
#
# FINANCIAL CHARACTERISTICS FOR HOUSING UNITS WITH A MORTGAGE
#
# Although the American Community Survey (ACS) produces population, demographic and housing unit estimates, it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities, and towns and estimates of housing units for states and counties.
#
#
# Supporting documentation on code lists, subject definitions, data accuracy, and statistical testing can be found on the American Community Survey website in the Technical Documentation section.
#
# Sample size and data quality measures (including coverage rates, allocation rates, and response rates) can be found on the American Community Survey website in the Methodology section.
#
#
# Source:  U.S. Census Bureau, 2013-2017 American Community Survey 5-Year Estimates
#
#
# Explanation of Symbols:An '**' entry in the margin of error column indicates that either no sample observations or too few sample observations were available to compute a standard error and thus the margin of error. A statistical test is not appropriate.
# An '-' entry in the estimate column indicates that either no sample observations or too few sample observations were available to compute an estimate, or a ratio of medians cannot be calculated because one or both of the median estimates falls in the lowest interval or upper interval of an open-ended distribution.
# An '-' following a median estimate means the median falls in the lowest interval of an open-ended distribution.
# An '+' following a median estimate means the median falls in the upper interval of an open-ended distribution.
# An '***' entry in the margin of error column indicates that the median falls in the lowest interval or upper interval of an open-ended distribution. A statistical test is not appropriate.
# An '*****' entry in the margin of error column indicates that the estimate is controlled. A statistical test for sampling variability is not appropriate.
# An 'N' entry in the estimate and margin of error columns indicates that data for this geographic area cannot be displayed because the number of sample cases is too small.
# An '(X)' means that the estimate is not applicable or not available.
#
#
# Data are based on a sample and are subject to sampling variability. The degree of uncertainty for an estimate arising from sampling variability is represented through the use of a margin of error. The value shown here is the 90 percent margin of error. The margin of error can be interpreted roughly as providing a 90 percent probability that the interval defined by the estimate minus the margin of error and the estimate plus the margin of error (the lower and upper confidence bounds) contains the true value. In addition to sampling variability, the ACS estimates are subject to nonsampling error (for a discussion of nonsampling variability, see Accuracy of the Data).  The effect of nonsampling error is not represented in these tables.
#
#
# While the 2013-2017 American Community Survey (ACS) data generally reflect the February 2013 Office of Management and Budget (OMB) definitions of metropolitan and micropolitan statistical areas; in certain instances the names, codes, and boundaries of the principal cities shown in ACS tables may differ from the OMB definitions due to differences in the effective dates of the geographic entities.
#
#
# Estimates of urban and rural populations, housing units, and characteristics reflect boundaries of urban areas defined based on Census 2010 data. As a result, data for urban and rural areas from the ACS do not necessarily reflect the results of ongoing urbanization.

# %% [markdown]
# ## ACS_17_5YR_S2506 HOUSING UNITS WITH MORTGAGE By County
# <a id='ACS_17_5YR_S2506'></a>
#
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# # ACS_17_5YR_S2506
#
# FINANCIAL CHARACTERISTICS FOR HOUSING UNITS WITH A MORTGAGE By County
#
# Although the American Community Survey (ACS) produces population, demographic and housing unit estimates, it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities, and towns and estimates of housing units for states and counties.
#
#
# Supporting documentation on code lists, subject definitions, data accuracy, and statistical testing can be found on the American Community Survey website in the Technical Documentation section.
#
# Sample size and data quality measures (including coverage rates, allocation rates, and response rates) can be found on the American Community Survey website in the Methodology section.
#
#
# Source:  U.S. Census Bureau, 2013-2017 American Community Survey 5-Year Estimates
#
#
# Explanation of Symbols:An '**' entry in the margin of error column indicates that either no sample observations or too few sample observations were available to compute a standard error and thus the margin of error. A statistical test is not appropriate.
# An '-' entry in the estimate column indicates that either no sample observations or too few sample observations were available to compute an estimate, or a ratio of medians cannot be calculated because one or both of the median estimates falls in the lowest interval or upper interval of an open-ended distribution.
# An '-' following a median estimate means the median falls in the lowest interval of an open-ended distribution.
# An '+' following a median estimate means the median falls in the upper interval of an open-ended distribution.
# An '***' entry in the margin of error column indicates that the median falls in the lowest interval or upper interval of an open-ended distribution. A statistical test is not appropriate.
# An '*****' entry in the margin of error column indicates that the estimate is controlled. A statistical test for sampling variability is not appropriate.
# An 'N' entry in the estimate and margin of error columns indicates that data for this geographic area cannot be displayed because the number of sample cases is too small.
# An '(X)' means that the estimate is not applicable or not available.
#
#
# Data are based on a sample and are subject to sampling variability. The degree of uncertainty for an estimate arising from sampling variability is represented through the use of a margin of error. The value shown here is the 90 percent margin of error. The margin of error can be interpreted roughly as providing a 90 percent probability that the interval defined by the estimate minus the margin of error and the estimate plus the margin of error (the lower and upper confidence bounds) contains the true value. In addition to sampling variability, the ACS estimates are subject to nonsampling error (for a discussion of nonsampling variability, see Accuracy of the Data).  The effect of nonsampling error is not represented in these tables.
#
#
# While the 2013-2017 American Community Survey (ACS) data generally reflect the February 2013 Office of Management and Budget (OMB) definitions of metropolitan and micropolitan statistical areas; in certain instances the names, codes, and boundaries of the principal cities shown in ACS tables may differ from the OMB definitions due to differences in the effective dates of the geographic entities.
#
#
# Estimates of urban and rural populations, housing units, and characteristics reflect boundaries of urban areas defined based on Census 2010 data. As a result, data for urban and rural areas from the ACS do not necessarily reflect the results of ongoing urbanization.

# %%
metaS2506 = pd.read_csv('ACS_17_5YR_S2506_metadata.csv')
metaS2506
# Out:
#                 GEO.id                                                                                                                                                                                             Id
# 0              GEO.id2                                                                                                                                                                                            Id2
# 1    GEO.display-label                                                                                                                                                                                      Geography
# 2        HC01_EST_VC01                                                                                           Owner-occupied housing units with a mortgage; Estimate; Owner-occupied housing units with a mortgage
# 3        HC01_MOE_VC01                                                                                    Owner-occupied housing units with a mortgage; Margin of Error; Owner-occupied housing units with a mortgage
# 4        HC02_EST_VC01                                                                                   Percent owner-occupied housing units with a mortgage; Estimate; Owner-occupied housing units with a mortgage
# 5        HC02_MOE_VC01                                                                            Percent owner-occupied housing units with a mortgage; Margin of Error; Owner-occupied housing units with a mortgage
# 6        HC01_EST_VC03                                                                                                              Owner-occupied housing units with a mortgage; Estimate; VALUE - Less than $50,000
# 7        HC01_MOE_VC03                                                                                                       Owner-occupied housing units with a mortgage; Margin of Error; VALUE - Less than $50,000
# 8        HC02_EST_VC03                                                                                                      Percent owner-occupied housing units with a mortgage; Estimate; VALUE - Less than $50,000
# 9        HC02_MOE_VC03                                                                                               Percent owner-occupied housing units with a mortgage; Margin of Error; VALUE - Less than $50,000
# 10       HC01_EST_VC04                                                                                                             Owner-occupied housing units with a mortgage; Estimate; VALUE - $50,000 to $99,999
# 11       HC01_MOE_VC04                                                                                                      Owner-occupied housing units with a mortgage; Margin of Error; VALUE - $50,000 to $99,999
# 12       HC02_EST_VC04                                                                                                     Percent owner-occupied housing units with a mortgage; Estimate; VALUE - $50,000 to $99,999
# 13       HC02_MOE_VC04                                                                                              Percent owner-occupied housing units with a mortgage; Margin of Error; VALUE - $50,000 to $99,999
# 14       HC01_EST_VC05                                                                                                           Owner-occupied housing units with a mortgage; Estimate; VALUE - $100,000 to $299,999
# 15       HC01_MOE_VC05                                                                                                    Owner-occupied housing units with a mortgage; Margin of Error; VALUE - $100,000 to $299,999
# 16       HC02_EST_VC05                                                                                                   Percent owner-occupied housing units with a mortgage; Estimate; VALUE - $100,000 to $299,999
# 17       HC02_MOE_VC05                                                                                            Percent owner-occupied housing units with a mortgage; Margin of Error; VALUE - $100,000 to $299,999
# 18       HC01_EST_VC06                                                                                                           Owner-occupied housing units with a mortgage; Estimate; VALUE - $300,000 to $499,999
# 19       HC01_MOE_VC06                                                                                                    Owner-occupied housing units with a mortgage; Margin of Error; VALUE - $300,000 to $499,999
# 20       HC02_EST_VC06                                                                                                   Percent owner-occupied housing units with a mortgage; Estimate; VALUE - $300,000 to $499,999
# 21       HC02_MOE_VC06                                                                                            Percent owner-occupied housing units with a mortgage; Margin of Error; VALUE - $300,000 to $499,999
# 22       HC01_EST_VC07                                                                                                           Owner-occupied housing units with a mortgage; Estimate; VALUE - $500,000 to $749,999
# 23       HC01_MOE_VC07                                                                                                    Owner-occupied housing units with a mortgage; Margin of Error; VALUE - $500,000 to $749,999
# 24       HC02_EST_VC07                                                                                                   Percent owner-occupied housing units with a mortgage; Estimate; VALUE - $500,000 to $749,999
# 25       HC02_MOE_VC07                                                                                            Percent owner-occupied housing units with a mortgage; Margin of Error; VALUE - $500,000 to $749,999
# 26       HC01_EST_VC08                                                                                                           Owner-occupied housing units with a mortgage; Estimate; VALUE - $750,000 to $999,999
# 27       HC01_MOE_VC08                                                                                                    Owner-occupied housing units with a mortgage; Margin of Error; VALUE - $750,000 to $999,999
# 28       HC02_EST_VC08                                                                                                   Percent owner-occupied housing units with a mortgage; Estimate; VALUE - $750,000 to $999,999
# 29       HC02_MOE_VC08                                                                                            Percent owner-occupied housing units with a mortgage; Margin of Error; VALUE - $750,000 to $999,999
# ..                 ...                                                                                                                                                                                            ...
# 232      HC02_EST_VC69           Percent owner-occupied housing units with a mortgage; Estimate; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 20 to 29 percent
# 233      HC02_MOE_VC69    Percent owner-occupied housing units with a mortgage; Margin of Error; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 20 to 29 percent
# 234      HC01_EST_VC70                 Owner-occupied housing units with a mortgage; Estimate; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 30 percent or more
# 235      HC01_MOE_VC70          Owner-occupied housing units with a mortgage; Margin of Error; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 30 percent or more
# 236      HC02_EST_VC70         Percent owner-occupied housing units with a mortgage; Estimate; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 30 percent or more
# 237      HC02_MOE_VC70  Percent owner-occupied housing units with a mortgage; Margin of Error; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 30 percent or more
# 238      HC01_EST_VC71                              Owner-occupied housing units with a mortgage; Estimate; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Zero or negative income
# 239      HC01_MOE_VC71                       Owner-occupied housing units with a mortgage; Margin of Error; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Zero or negative income
# 240      HC02_EST_VC71                      Percent owner-occupied housing units with a mortgage; Estimate; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Zero or negative income
# 241      HC02_MOE_VC71               Percent owner-occupied housing units with a mortgage; Margin of Error; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Zero or negative income
# 242      HC01_EST_VC74                                                                                                     Owner-occupied housing units with a mortgage; Estimate; REAL ESTATE TAXES - Less than $800
# 243      HC01_MOE_VC74                                                                                              Owner-occupied housing units with a mortgage; Margin of Error; REAL ESTATE TAXES - Less than $800
# 244      HC02_EST_VC74                                                                                             Percent owner-occupied housing units with a mortgage; Estimate; REAL ESTATE TAXES - Less than $800
# 245      HC02_MOE_VC74                                                                                      Percent owner-occupied housing units with a mortgage; Margin of Error; REAL ESTATE TAXES - Less than $800
# 246      HC01_EST_VC75                                                                                                     Owner-occupied housing units with a mortgage; Estimate; REAL ESTATE TAXES - $800 to $1,499
# 247      HC01_MOE_VC75                                                                                              Owner-occupied housing units with a mortgage; Margin of Error; REAL ESTATE TAXES - $800 to $1,499
# 248      HC02_EST_VC75                                                                                             Percent owner-occupied housing units with a mortgage; Estimate; REAL ESTATE TAXES - $800 to $1,499
# 249      HC02_MOE_VC75                                                                                      Percent owner-occupied housing units with a mortgage; Margin of Error; REAL ESTATE TAXES - $800 to $1,499
# 250      HC01_EST_VC76                                                                                                     Owner-occupied housing units with a mortgage; Estimate; REAL ESTATE TAXES - $1,500 or more
# 251      HC01_MOE_VC76                                                                                              Owner-occupied housing units with a mortgage; Margin of Error; REAL ESTATE TAXES - $1,500 or more
# 252      HC02_EST_VC76                                                                                             Percent owner-occupied housing units with a mortgage; Estimate; REAL ESTATE TAXES - $1,500 or more
# 253      HC02_MOE_VC76                                                                                      Percent owner-occupied housing units with a mortgage; Margin of Error; REAL ESTATE TAXES - $1,500 or more
# 254      HC01_EST_VC77                                                                                          Owner-occupied housing units with a mortgage; Estimate; REAL ESTATE TAXES - No real estate taxes paid
# 255      HC01_MOE_VC77                                                                                   Owner-occupied housing units with a mortgage; Margin of Error; REAL ESTATE TAXES - No real estate taxes paid
# 256      HC02_EST_VC77                                                                                  Percent owner-occupied housing units with a mortgage; Estimate; REAL ESTATE TAXES - No real estate taxes paid
# 257      HC02_MOE_VC77                                                                           Percent owner-occupied housing units with a mortgage; Margin of Error; REAL ESTATE TAXES - No real estate taxes paid
# 258      HC01_EST_VC78                                                                                                   Owner-occupied housing units with a mortgage; Estimate; REAL ESTATE TAXES - Median (dollars)
# 259      HC01_MOE_VC78                                                                                            Owner-occupied housing units with a mortgage; Margin of Error; REAL ESTATE TAXES - Median (dollars)
# 260      HC02_EST_VC78                                                                                           Percent owner-occupied housing units with a mortgage; Estimate; REAL ESTATE TAXES - Median (dollars)
# 261      HC02_MOE_VC78                                                                                    Percent owner-occupied housing units with a mortgage; Margin of Error; REAL ESTATE TAXES - Median (dollars)
#
# [262 rows x 2 columns]

# %%
dataS2506 = pd.read_csv('ACS_17_5YR_S2506_with_ann.csv')
dataS2506.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Columns: 263 entries, GEO.id to HC02_MOE_VC78
# dtypes: object(263)
# memory usage: 199.4+ KB

# %%
dataS2506['GEO.display-label'].head()
# Out:
# 0                     Geography
# 1                     Tennessee
# 2    Anderson County, Tennessee
# 3     Bedford County, Tennessee
# 4      Benton County, Tennessee
# Name: GEO.display-label, dtype: object

# %%
ls
# Out:
# ACS_17_5YR_B25075_metadata.csv  ACS_17_5YR_S2507_metadata.csv
# ACS_17_5YR_B25075.txt           ACS_17_5YR_S2507.txt
# ACS_17_5YR_B25075_with_ann.csv  ACS_17_5YR_S2507_with_ann.csv
# ACS_17_5YR_S2506_metadata.csv   aff_download3.zip
# ACS_17_5YR_S2506.txt            aff_download_readme_ann.txt
# ACS_17_5YR_S2506_with_ann.csv   data.ipynb

# %% [markdown]
# ## ACS_17_5YR_S2507 HOUSING UNITS WITHOUT MORTGAGE  By County
# <a id='ACS_17_5YR_S2507'></a>
#
#
# [Table of Contents](#Table_of_Contents)

# %% [markdown]
# # ACS_17_5YR_S2507 HOUSING UNITS WITHOUT MORTGAGE  By County
#
# FINANCIAL CHARACTERISTICS FOR HOUSING UNITS WITHOUT A MORTGAGE  By County
#
# Although the American Community Survey (ACS) produces population, demographic and housing unit estimates, it is the Census Bureau's Population Estimates Program that produces and disseminates the official estimates of the population for the nation, states, counties, cities, and towns and estimates of housing units for states and counties.
#
#
# Supporting documentation on code lists, subject definitions, data accuracy, and statistical testing can be found on the American Community Survey website in the Technical Documentation section.
#
# Sample size and data quality measures (including coverage rates, allocation rates, and response rates) can be found on the American Community Survey website in the Methodology section.
#
#
# Source:  U.S. Census Bureau, 2013-2017 American Community Survey 5-Year Estimates
#
#
# Explanation of Symbols:An '**' entry in the margin of error column indicates that either no sample observations or too few sample observations were available to compute a standard error and thus the margin of error. A statistical test is not appropriate.
# An '-' entry in the estimate column indicates that either no sample observations or too few sample observations were available to compute an estimate, or a ratio of medians cannot be calculated because one or both of the median estimates falls in the lowest interval or upper interval of an open-ended distribution.
# An '-' following a median estimate means the median falls in the lowest interval of an open-ended distribution.
# An '+' following a median estimate means the median falls in the upper interval of an open-ended distribution.
# An '***' entry in the margin of error column indicates that the median falls in the lowest interval or upper interval of an open-ended distribution. A statistical test is not appropriate.
# An '*****' entry in the margin of error column indicates that the estimate is controlled. A statistical test for sampling variability is not appropriate.
# An 'N' entry in the estimate and margin of error columns indicates that data for this geographic area cannot be displayed because the number of sample cases is too small.
# An '(X)' means that the estimate is not applicable or not available.
#
#
# Data are based on a sample and are subject to sampling variability. The degree of uncertainty for an estimate arising from sampling variability is represented through the use of a margin of error. The value shown here is the 90 percent margin of error. The margin of error can be interpreted roughly as providing a 90 percent probability that the interval defined by the estimate minus the margin of error and the estimate plus the margin of error (the lower and upper confidence bounds) contains the true value. In addition to sampling variability, the ACS estimates are subject to nonsampling error (for a discussion of nonsampling variability, see Accuracy of the Data).  The effect of nonsampling error is not represented in these tables.
#
#
# While the 2013-2017 American Community Survey (ACS) data generally reflect the February 2013 Office of Management and Budget (OMB) definitions of metropolitan and micropolitan statistical areas; in certain instances the names, codes, and boundaries of the principal cities shown in ACS tables may differ from the OMB definitions due to differences in the effective dates of the geographic entities.
#
#
# Estimates of urban and rural populations, housing units, and characteristics reflect boundaries of urban areas defined based on Census 2010 data. As a result, data for urban and rural areas from the ACS do not necessarily reflect the results of ongoing urbanization.

# %%
metaS2507 = pd.read_csv('ACS_17_5YR_S2507_metadata.csv')
metaS2507
# Out:
#                 GEO.id                                                                                                                                                                                                Id
# 0              GEO.id2                                                                                                                                                                                               Id2
# 1    GEO.display-label                                                                                                                                                                                         Geography
# 2        HC01_EST_VC01                                                                                        Owner-occupied housing units without a mortgage; Estimate; Owner-occupied housing units without a mortgage
# 3        HC01_MOE_VC01                                                                                 Owner-occupied housing units without a mortgage; Margin of Error; Owner-occupied housing units without a mortgage
# 4        HC02_EST_VC01                                                                                Percent owner-occupied housing units without a mortgage; Estimate; Owner-occupied housing units without a mortgage
# 5        HC02_MOE_VC01                                                                         Percent owner-occupied housing units without a mortgage; Margin of Error; Owner-occupied housing units without a mortgage
# 6        HC01_EST_VC03                                                                                                              Owner-occupied housing units without a mortgage; Estimate; VALUE - Less than $50,000
# 7        HC01_MOE_VC03                                                                                                       Owner-occupied housing units without a mortgage; Margin of Error; VALUE - Less than $50,000
# 8        HC02_EST_VC03                                                                                                      Percent owner-occupied housing units without a mortgage; Estimate; VALUE - Less than $50,000
# 9        HC02_MOE_VC03                                                                                               Percent owner-occupied housing units without a mortgage; Margin of Error; VALUE - Less than $50,000
# 10       HC01_EST_VC04                                                                                                             Owner-occupied housing units without a mortgage; Estimate; VALUE - $50,000 to $99,999
# 11       HC01_MOE_VC04                                                                                                      Owner-occupied housing units without a mortgage; Margin of Error; VALUE - $50,000 to $99,999
# 12       HC02_EST_VC04                                                                                                     Percent owner-occupied housing units without a mortgage; Estimate; VALUE - $50,000 to $99,999
# 13       HC02_MOE_VC04                                                                                              Percent owner-occupied housing units without a mortgage; Margin of Error; VALUE - $50,000 to $99,999
# 14       HC01_EST_VC05                                                                                                           Owner-occupied housing units without a mortgage; Estimate; VALUE - $100,000 to $199,999
# 15       HC01_MOE_VC05                                                                                                    Owner-occupied housing units without a mortgage; Margin of Error; VALUE - $100,000 to $199,999
# 16       HC02_EST_VC05                                                                                                   Percent owner-occupied housing units without a mortgage; Estimate; VALUE - $100,000 to $199,999
# 17       HC02_MOE_VC05                                                                                            Percent owner-occupied housing units without a mortgage; Margin of Error; VALUE - $100,000 to $199,999
# 18       HC01_EST_VC06                                                                                                           Owner-occupied housing units without a mortgage; Estimate; VALUE - $200,000 to $299,999
# 19       HC01_MOE_VC06                                                                                                    Owner-occupied housing units without a mortgage; Margin of Error; VALUE - $200,000 to $299,999
# 20       HC02_EST_VC06                                                                                                   Percent owner-occupied housing units without a mortgage; Estimate; VALUE - $200,000 to $299,999
# 21       HC02_MOE_VC06                                                                                            Percent owner-occupied housing units without a mortgage; Margin of Error; VALUE - $200,000 to $299,999
# 22       HC01_EST_VC07                                                                                                           Owner-occupied housing units without a mortgage; Estimate; VALUE - $300,000 to $499,999
# 23       HC01_MOE_VC07                                                                                                    Owner-occupied housing units without a mortgage; Margin of Error; VALUE - $300,000 to $499,999
# 24       HC02_EST_VC07                                                                                                   Percent owner-occupied housing units without a mortgage; Estimate; VALUE - $300,000 to $499,999
# 25       HC02_MOE_VC07                                                                                            Percent owner-occupied housing units without a mortgage; Margin of Error; VALUE - $300,000 to $499,999
# 26       HC01_EST_VC08                                                                                                           Owner-occupied housing units without a mortgage; Estimate; VALUE - $500,000 to $749,999
# 27       HC01_MOE_VC08                                                                                                    Owner-occupied housing units without a mortgage; Margin of Error; VALUE - $500,000 to $749,999
# 28       HC02_EST_VC08                                                                                                   Percent owner-occupied housing units without a mortgage; Estimate; VALUE - $500,000 to $749,999
# 29       HC02_MOE_VC08                                                                                            Percent owner-occupied housing units without a mortgage; Margin of Error; VALUE - $500,000 to $749,999
# ..                 ...                                                                                                                                                                                               ...
# 204      HC02_EST_VC60           Percent owner-occupied housing units without a mortgage; Estimate; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 20 to 29 percent
# 205      HC02_MOE_VC60    Percent owner-occupied housing units without a mortgage; Margin of Error; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 20 to 29 percent
# 206      HC01_EST_VC61                 Owner-occupied housing units without a mortgage; Estimate; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 30 percent or more
# 207      HC01_MOE_VC61          Owner-occupied housing units without a mortgage; Margin of Error; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 30 percent or more
# 208      HC02_EST_VC61         Percent owner-occupied housing units without a mortgage; Estimate; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 30 percent or more
# 209      HC02_MOE_VC61  Percent owner-occupied housing units without a mortgage; Margin of Error; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - $75,000 or more - 30 percent or more
# 210      HC01_EST_VC62                              Owner-occupied housing units without a mortgage; Estimate; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Zero or negative income
# 211      HC01_MOE_VC62                       Owner-occupied housing units without a mortgage; Margin of Error; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Zero or negative income
# 212      HC02_EST_VC62                      Percent owner-occupied housing units without a mortgage; Estimate; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Zero or negative income
# 213      HC02_MOE_VC62               Percent owner-occupied housing units without a mortgage; Margin of Error; MONTHLY HOUSING COSTS AS A PERCENTAGE OF HOUSEHOLD INCOME IN THE PAST 12 MONTHS - Zero or negative income
# 214      HC01_EST_VC65                                                                                                     Owner-occupied housing units without a mortgage; Estimate; REAL ESTATE TAXES - Less than $800
# 215      HC01_MOE_VC65                                                                                              Owner-occupied housing units without a mortgage; Margin of Error; REAL ESTATE TAXES - Less than $800
# 216      HC02_EST_VC65                                                                                             Percent owner-occupied housing units without a mortgage; Estimate; REAL ESTATE TAXES - Less than $800
# 217      HC02_MOE_VC65                                                                                      Percent owner-occupied housing units without a mortgage; Margin of Error; REAL ESTATE TAXES - Less than $800
# 218      HC01_EST_VC66                                                                                                     Owner-occupied housing units without a mortgage; Estimate; REAL ESTATE TAXES - $800 to $1,499
# 219      HC01_MOE_VC66                                                                                              Owner-occupied housing units without a mortgage; Margin of Error; REAL ESTATE TAXES - $800 to $1,499
# 220      HC02_EST_VC66                                                                                             Percent owner-occupied housing units without a mortgage; Estimate; REAL ESTATE TAXES - $800 to $1,499
# 221      HC02_MOE_VC66                                                                                      Percent owner-occupied housing units without a mortgage; Margin of Error; REAL ESTATE TAXES - $800 to $1,499
# 222      HC01_EST_VC67                                                                                                     Owner-occupied housing units without a mortgage; Estimate; REAL ESTATE TAXES - $1,500 or more
# 223      HC01_MOE_VC67                                                                                              Owner-occupied housing units without a mortgage; Margin of Error; REAL ESTATE TAXES - $1,500 or more
# 224      HC02_EST_VC67                                                                                             Percent owner-occupied housing units without a mortgage; Estimate; REAL ESTATE TAXES - $1,500 or more
# 225      HC02_MOE_VC67                                                                                      Percent owner-occupied housing units without a mortgage; Margin of Error; REAL ESTATE TAXES - $1,500 or more
# 226      HC01_EST_VC68                                                                                          Owner-occupied housing units without a mortgage; Estimate; REAL ESTATE TAXES - No real estate taxes paid
# 227      HC01_MOE_VC68                                                                                   Owner-occupied housing units without a mortgage; Margin of Error; REAL ESTATE TAXES - No real estate taxes paid
# 228      HC02_EST_VC68                                                                                  Percent owner-occupied housing units without a mortgage; Estimate; REAL ESTATE TAXES - No real estate taxes paid
# 229      HC02_MOE_VC68                                                                           Percent owner-occupied housing units without a mortgage; Margin of Error; REAL ESTATE TAXES - No real estate taxes paid
# 230      HC01_EST_VC69                                                                                                   Owner-occupied housing units without a mortgage; Estimate; REAL ESTATE TAXES - Median (dollars)
# 231      HC01_MOE_VC69                                                                                            Owner-occupied housing units without a mortgage; Margin of Error; REAL ESTATE TAXES - Median (dollars)
# 232      HC02_EST_VC69                                                                                           Percent owner-occupied housing units without a mortgage; Estimate; REAL ESTATE TAXES - Median (dollars)
# 233      HC02_MOE_VC69                                                                                    Percent owner-occupied housing units without a mortgage; Margin of Error; REAL ESTATE TAXES - Median (dollars)
#
# [234 rows x 2 columns]

# %%
dataS2507 = pd.read_csv('ACS_17_5YR_S2507_with_ann.csv')
dataS2507.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Columns: 235 entries, GEO.id to HC02_MOE_VC69
# dtypes: object(235)
# memory usage: 178.2+ KB

# %%
dataS2507['GEO.display-label'].head()
# Out:
# 0                     Geography
# 1                     Tennessee
# 2    Anderson County, Tennessee
# 3     Bedford County, Tennessee
# 4      Benton County, Tennessee
# Name: GEO.display-label, dtype: object
